# %% [markdown]
# # Aggregation
#
# ## 场景一
#
# ### (1) 描述
#
# 场景一中，所有实验按固定的模式运行，包含干扰循环和负载循环
# 1. 初始化 client 和 server(vm)
# 2. 启动 background 干扰，当前支持的干扰有: cpu/cache/mem/io/net
# 3. 启动 workload， 当前支持的workload有: redis/nginx/mysql
# 4. workload 结束后，记录一份 `workload_info`, 包含时间戳, 负载、干扰强度等metadata
# 5. 回到步骤3，执行下一个workload，当所有workload都执行完毕后，记录一份 `info_per_epoch`, 包含所有已经执行的 `workload_info`, 以及此次循环的干扰强度信息
# 6. 回到步骤2，直到所有的强度的干扰都指向完毕
# 7. 结束实验，记录实验的启动、结束时间，总共消耗的时间，以及干扰循环的总次数
#
# 以上信息保存在 `exp.json` 或 `date.json` 中，另外通过 Prometheus client 请求得到整个实验周期中的metric数据，保存在 `merged.csv` 中

# %% [markdown]
# ### (2) 数据处理
#
#
# #### 1. Quick Start
#
#
# 通过 `read_from_dir(dir)` 读取 metadata 和csv 数据创建 `ExpData` 实例

# %%
from aggregation import *
pd.set_option('display.max_rows', 10) 

exp_root = "/home/ict/appProfile/data/addtion_exp/standard_stress_cache_20231023055534/"
exp_data = read_from_dir(exp_root)

# %% [markdown]
# 调用 `agg_epoch()` 方法之后，`exp_data` 会按每次干扰循环聚合数据, 这也是推荐的使用方法

# %%
df_epoch = exp_data.agg_epoch()
df_epoch
# Out:
#          stress_cache  host_cache_llc_capacity_numa_0  \
# redis_0             1                        0.969117
# redis_1             1                        0.970935
# redis_2             1                        0.965691
# redis_3             1                        0.961199
# redis_4             1                        0.962216
# ...               ...                             ...
# redis_4            32                        0.969518
# redis_5            32                        0.960313
# redis_6            32                        0.953977
# redis_7            32                        0.941974
# redis_8            32                        0.947984
#
#          host_cache_llc_capacity_numa_1  host_cache_llc_capacity_numa_2  \
# redis_0                        0.932368                        0.986070
# redis_1                        0.945950                        0.976326
# redis_2                        0.944784                        0.983974
# redis_3                        0.938023                        0.973161
# redis_4                        0.938068                        0.977273
# ...                                 ...                             ...
# redis_4                        0.955313                        0.990940
# redis_5                        0.946970                        0.988636
# redis_6                        0.946378                        0.983239
# redis_7                        0.945810                        0.991335
# redis_8                        0.915517                        0.992898
#
#          host_cache_llc_capacity_numa_3  host_kernel_context_switch  \
# redis_0                        0.977731                90670.274194
# redis_1                        0.976399               114668.628205
# redis_2                        0.976471               132115.717949
# redis_3                        0.978843               130271.881579
# redis_4                        0.975142               126330.525000
# ...                                 ...                         ...
# redis_4                        0.975814                65809.148649
# redis_5                        0.977445                71897.060606
# redis_6                        0.975355                79040.350000
# redis_7                        0.970810                75544.512500
# redis_8                        0.976123                69654.952381
#
#          host_kernel_interrupt  host_kernel_thread_fork_fork  \
# redis_0           85881.451613                      0.112903
# redis_1          117440.076923                      0.282051
# redis_2          115039.717949                      0.269231
# redis_3          110798.842105                      0.105263
# redis_4          103445.037500                      0.100000
# ...                        ...                           ...
# redis_4           70026.445946                      0.378378
# redis_5           79683.272727                      0.136364
# redis_6           89192.425000                      0.150000
# redis_7           84729.450000                      0.437500
# redis_8           75430.202381                      0.333333
#
#          host_kernel_syscall_accept  host_kernel_syscall_accept4  ...  \
# redis_0                    0.564516                     0.129032  ...
# redis_1                    0.576923                     0.128205  ...
# redis_2                    0.000000                     0.000000  ...
# redis_3                    0.526316                     0.052632  ...
# redis_4                    0.000000                     0.000000  ...
# ...                             ...                          ...  ...
# redis_4                    0.567568                     0.027027  ...
# redis_5                    0.560606                     0.090909  ...
# redis_6                    0.612500                     0.125000  ...
# redis_7                    0.600000                     0.150000  ...
# redis_8                    0.571429                     0.142857  ...
#
#          host_kernel_syscall_sendmmsg  host_kernel_syscall_inotify_rm_watch  \
# redis_0                           0.0                                   0.0
# redis_1                           0.0                                   0.0
# redis_2                           0.0                                   0.0
# redis_3                           0.0                                   0.0
# redis_4                           0.0                                   0.0
# ...                               ...                                   ...
# redis_4                           0.0                                   0.0
# redis_5                           0.0                                   0.0
# redis_6                           0.0                                   0.0
# redis_7                           0.0                                   0.0
# redis_8                           0.0                                   0.0
#
#          host_kernel_syscall_rmdir  host_kernel_syscall_statx  \
# redis_0                        0.0                        0.0
# redis_1                        0.0                        0.0
# redis_2                        0.0                        0.0
# redis_3                        0.0                        0.0
# redis_4                        0.0                        0.0
# ...                            ...                        ...
# redis_4                        0.0                        0.0
# redis_5                        0.0                        0.0
# redis_6                        0.0                        0.0
# redis_7                        0.0                        0.0
# redis_8                        0.0                        0.0
#
#          host_kernel_syscall_umount2  host_kernel_syscall_unlinkat  \
# redis_0                          0.0                           0.0
# redis_1                          0.0                           0.0
# redis_2                          0.0                           0.0
# redis_3                          0.0                           0.0
# redis_4                          0.0                           0.0
# ...                              ...                           ...
# redis_4                          0.0                           0.0
# redis_5                          0.0                           0.0
# redis_6                          0.0                           0.0
# redis_7                          0.0                           0.0
# redis_8                          0.0                           0.0
#
#          host_kernel_syscall_fallocate  host_kernel_syscall_getpgid  \
# redis_0                            0.0                          0.0
# redis_1                            0.0                          0.0
# redis_2                            0.0                          0.0
# redis_3                            0.0                          0.0
# redis_4                            0.0                          0.0
# ...                                ...                          ...
# redis_4                            0.0                          0.0
# redis_5                            0.0                          0.0
# redis_6                            0.0                          0.0
# redis_7                            0.0                          0.0
# redis_8                            0.0                          0.0
#
#          vm_hypervisor_emulator_syscall_count_fallocate  \
# redis_0                                             0.0
# redis_1                                             0.0
# redis_2                                             0.0
# redis_3                                             0.0
# redis_4                                             0.0
# ...                                                 ...
# redis_4                                             0.0
# redis_5                                             0.0
# redis_6                                             0.0
# redis_7                                             0.0
# redis_8                                             0.0
#
#          vm_hypervisor_emulator_syscall_duration_fallocate
# redis_0                                                0.0
# redis_1                                                0.0
# redis_2                                                0.0
# redis_3                                                0.0
# redis_4                                                0.0
# ...                                                    ...
# redis_4                                                0.0
# redis_5                                                0.0
# redis_6                                                0.0
# redis_7                                                0.0
# redis_8                                                0.0
#
# [54 rows x 261 columns]

# %% [markdown]
# 因为返回的仍然是一个 DataFrame, 因此后续可以根据数据处理的需要自行设置方法，如下展示一种从 `df_epoch` 数据中获取某个 workload 数据的流程

# %%
df_epoch_group = df_epoch.groupby(df_epoch.index)
keys = list(df_epoch_group.groups.keys())
keys
# Out:
# ['redis_0',
#  'redis_1',
#  'redis_2',
#  'redis_3',
#  'redis_4',
#  'redis_5',
#  'redis_6',
#  'redis_7',
#  'redis_8']

# %% [markdown]
# 使用 `groupby` 函数处理 Dataframe, 并从 `groups.keys()` 选择一个获取此 workload 的数据

# %%
df_workload = df_epoch_group.get_group(keys[0])
df_workload
# Out:
#          stress_cache  host_cache_llc_capacity_numa_0  \
# redis_0             1                        0.969117
# redis_0             2                        0.964598
# redis_0             4                        0.974165
# redis_0             8                        0.971053
# redis_0            16                        0.963618
# redis_0            32                        0.963710
#
#          host_cache_llc_capacity_numa_1  host_cache_llc_capacity_numa_2  \
# redis_0                        0.932368                        0.986070
# redis_0                        0.926792                        0.994974
# redis_0                        0.930842                        0.986239
# redis_0                        0.926904                        0.987024
# redis_0                        0.945381                        0.979472
# redis_0                        0.946023                        0.979839
#
#          host_cache_llc_capacity_numa_3  host_kernel_context_switch  \
# redis_0                        0.977731                90670.274194
# redis_0                        0.982517                87441.102564
# redis_0                        0.976385                88772.750000
# redis_0                        0.977196                85025.918919
# redis_0                        0.968475                81288.870968
# redis_0                        0.973057                89208.370968
#
#          host_kernel_interrupt  host_kernel_thread_fork_fork  \
# redis_0           85881.451613                      0.112903
# redis_0           84046.205128                      0.128205
# redis_0           85738.796875                      0.140625
# redis_0           84821.918919                      0.270270
# redis_0           83684.274194                      0.467742
# redis_0           94168.435484                      0.354839
#
#          host_kernel_syscall_accept  host_kernel_syscall_accept4  ...  \
# redis_0                    0.564516                     0.129032  ...
# redis_0                    0.000000                     0.000000  ...
# redis_0                    0.000000                     0.031250  ...
# redis_0                    0.513514                     0.000000  ...
# redis_0                    0.580645                     0.096774  ...
# redis_0                    0.612903                     0.064516  ...
#
#          host_kernel_syscall_sendmmsg  host_kernel_syscall_inotify_rm_watch  \
# redis_0                           0.0                              0.000000
# redis_0                           0.0                              0.000000
# redis_0                           0.0                              0.000000
# redis_0                           0.0                              0.000000
# redis_0                           0.0                              0.241935
# redis_0                           0.0                              0.000000
#
#          host_kernel_syscall_rmdir  host_kernel_syscall_statx  \
# redis_0                   0.000000                   0.000000
# redis_0                   0.000000                   0.000000
# redis_0                   0.000000                   0.000000
# redis_0                   0.000000                   0.000000
# redis_0                   0.048387                   0.032258
# redis_0                   0.000000                   0.000000
#
#          host_kernel_syscall_umount2  host_kernel_syscall_unlinkat  \
# redis_0                     0.000000                      0.000000
# redis_0                     0.000000                      0.000000
# redis_0                     0.000000                      0.000000
# redis_0                     0.000000                      0.000000
# redis_0                     0.016129                      0.032258
# redis_0                     0.000000                      0.000000
#
#          host_kernel_syscall_fallocate  host_kernel_syscall_getpgid  \
# redis_0                       0.000000                          0.0
# redis_0                       0.000000                          0.0
# redis_0                       0.000000                          0.0
# redis_0                       0.000000                          0.0
# redis_0                       0.000000                          0.0
# redis_0                       0.016129                          0.0
#
#          vm_hypervisor_emulator_syscall_count_fallocate  \
# redis_0                                        0.000000
# redis_0                                        0.000000
# redis_0                                        0.000000
# redis_0                                        0.000000
# redis_0                                        0.000000
# redis_0                                        0.016129
#
#          vm_hypervisor_emulator_syscall_duration_fallocate
# redis_0                                           0.000000
# redis_0                                           0.000000
# redis_0                                           0.000000
# redis_0                                           0.000000
# redis_0                                           0.000000
# redis_0                                           1.548387
#
# [6 rows x 261 columns]

# %% [markdown]
# #### 2. Custom Process
#
# `exp_data` 将读入的数据保存在 `exp` 与 `df` 两个字段中，可以通过 `exp_data.exp` 与 `exp_data.df` 来直接访问读入的数据， 如获取某个 workload info, 可以采取如下方式

# %%
workload_info = exp_data.exp["info_per_epoch"][0]["workloads"][keys[0]]
workload_info
# Out:
# {'start_time': 1698040546,
#  'run_cmd': 'docker exec -it redis-client-1 memtier_benchmark  -s envoy --test-time 160 -t 1',
#  'end_time': 1698040706,
#  'name': 'redis_0',
#  'stress': {'cache': {'cache': '1'}}}

# %% [markdown]
# 随后，可以使用” `workload_df` 来获取此 workload 对应的 dataframe

# %%
exp_data.workload_df(workload_info)
# Out:
#                host_cache_llc_capacity_numa_0  host_cache_llc_capacity_numa_1  \
# Time
# 1698040550000                        0.980114                        0.951705
# 1698040554000                        0.974432                        0.849432
# 1698040558000                        0.957386                        0.948864
# 1698040566000                        0.982955                        0.994318
# 1698040570000                        0.963068                        0.906250
# ...                                       ...                             ...
# 1698040690000                        0.965909                        0.960227
# 1698040694000                        0.982955                        0.914773
# 1698040698000                        0.957386                        0.940341
# 1698040702000                        0.965909                        0.917614
# 1698040706000                        0.954545                        0.951705
#
#                host_cache_llc_capacity_numa_2  host_cache_llc_capacity_numa_3  \
# Time
# 1698040550000                        0.977273                        0.988636
# 1698040554000                        0.991477                        0.982955
# 1698040558000                        0.991477                        0.980114
# 1698040566000                        0.971591                        0.988636
# 1698040570000                        0.994318                        0.963068
# ...                                       ...                             ...
# 1698040690000                        0.974432                        0.982955
# 1698040694000                        1.005682                        0.977273
# 1698040698000                        0.982955                        0.957386
# 1698040702000                        1.005682                        0.980114
# 1698040706000                        0.980114                        0.991477
#
#                host_kernel_context_switch  host_kernel_interrupt  \
# Time
# 1698040550000                     87495.0                83148.0
# 1698040554000                     88073.0                82286.0
# 1698040558000                     90041.5                84752.5
# 1698040566000                     88943.5                83581.5
# 1698040570000                     95489.0                89848.0
# ...                                   ...                    ...
# 1698040690000                     85645.5                82015.5
# 1698040694000                     92706.5                88314.5
# 1698040698000                     95659.5                89050.5
# 1698040702000                     85944.0                83846.5
# 1698040706000                     87596.0                83746.5
#
#                host_kernel_thread_fork_fork  host_kernel_syscall_accept  \
# Time
# 1698040550000                           0.0                         0.5
# 1698040554000                           0.0                         0.5
# 1698040558000                           0.0                         0.5
# 1698040566000                           0.0                         0.5
# 1698040570000                           0.0                         0.5
# ...                                     ...                         ...
# 1698040690000                           0.0                         0.5
# 1698040694000                           0.0                         1.0
# 1698040698000                           0.0                         0.5
# 1698040702000                           0.0                         0.5
# 1698040706000                           0.0                         0.5
#
#                host_kernel_syscall_accept4  host_kernel_syscall_access  ...  \
# Time                                                                    ...
# 1698040550000                          0.0                       329.5  ...
# 1698040554000                          0.0                       329.5  ...
# 1698040558000                          0.0                       329.5  ...
# 1698040566000                          0.0                       329.5  ...
# 1698040570000                          0.0                       329.5  ...
# ...                                    ...                         ...  ...
# 1698040690000                          0.0                       329.5  ...
# 1698040694000                          1.0                       330.5  ...
# 1698040698000                          0.0                       329.5  ...
# 1698040702000                          0.0                       329.5  ...
# 1698040706000                          0.0                       329.5  ...
#
#                vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# Time
# 1698040550000                           0                         0.0
# 1698040554000                           0                         0.0
# 1698040558000                           0                         0.0
# 1698040566000                           0                         0.0
# 1698040570000                       16384                         3.5
# ...                                   ...                         ...
# 1698040690000                           0                         0.0
# 1698040694000                           0                         0.0
# 1698040698000                           0                         0.0
# 1698040702000                           0                         0.0
# 1698040706000                           0                         0.0
#
#                vm_block_io_time_write  \
# Time
# 1698040550000                0.000000
# 1698040554000                0.000000
# 1698040558000                0.000000
# 1698040566000                0.000000
# 1698040570000                0.003391
# ...                               ...
# 1698040690000                0.000000
# 1698040694000                0.000000
# 1698040698000                0.000000
# 1698040702000                0.000000
# 1698040706000                0.000000
#
#                vm_block_io_flush_request_and_time_request_vda  \
# Time
# 1698040550000                                               0
# 1698040554000                                               0
# 1698040558000                                               0
# 1698040566000                                               0
# 1698040570000                                               0
# ...                                                       ...
# 1698040690000                                               0
# 1698040694000                                               0
# 1698040698000                                               0
# 1698040702000                                               0
# 1698040706000                                               0
#
#                vm_block_io_flush_request_and_time_time_vda  \
# Time
# 1698040550000                                          0.0
# 1698040554000                                          0.0
# 1698040558000                                          0.0
# 1698040566000                                          0.0
# 1698040570000                                          0.0
# ...                                                    ...
# 1698040690000                                          0.0
# 1698040694000                                          0.0
# 1698040698000                                          0.0
# 1698040702000                                          0.0
# 1698040706000                                          0.0
#
#                app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# Time
# 1698040550000                         39507.5                          3951.5
# 1698040554000                         38915.0                          3892.5
# 1698040558000                         39919.0                          3991.0
# 1698040566000                         40468.0                          4046.5
# 1698040570000                         41526.5                          4152.5
# ...                                       ...                             ...
# 1698040690000                         39026.5                          3901.5
# 1698040694000                         39406.5                          3942.5
# 1698040698000                         40355.0                          4032.5
# 1698040702000                         40401.5                          4043.0
# 1698040706000                         39677.0                          3967.5
#
#                app_redis_qos_qps_of_redis_total  \
# Time
# 1698040550000                           43459.0
# 1698040554000                           42807.5
# 1698040558000                           43910.0
# 1698040566000                           44514.5
# 1698040570000                           45679.0
# ...                                         ...
# 1698040690000                           42928.0
# 1698040694000                           43349.0
# 1698040698000                           44387.5
# 1698040702000                           44444.5
# 1698040706000                           43644.5
#
#                app_redis_qos_p99_latency_set  app_redis_qos_p99_latency_get
# Time
# 1698040550000                           0.99                       0.990000
# 1698040554000                           0.99                       0.990012
# 1698040558000                           0.99                       0.990026
# 1698040566000                           0.99                       0.990000
# 1698040570000                           0.99                       0.990000
# ...                                      ...                            ...
# 1698040690000                           0.99                       0.990000
# 1698040694000                           0.99                       0.990000
# 1698040698000                           0.99                       0.990012
# 1698040702000                           0.99                       0.990000
# 1698040706000                           0.99                       0.990000
#
# [31 rows x 180 columns]

# %% [markdown]
# 默认情况下不会提取 "stress" 数据，可以指定参数 `with_stress` 来开启

# %%
exp_data.workload_df(workload_info, with_stress=True)
# Out:
#                stress_cache  host_cache_llc_capacity_numa_0  \
# Time
# 1698040550000             1                        0.980114
# 1698040554000             1                        0.974432
# 1698040558000             1                        0.957386
# 1698040566000             1                        0.982955
# 1698040570000             1                        0.963068
# ...                     ...                             ...
# 1698040690000             1                        0.965909
# 1698040694000             1                        0.982955
# 1698040698000             1                        0.957386
# 1698040702000             1                        0.965909
# 1698040706000             1                        0.954545
#
#                host_cache_llc_capacity_numa_1  host_cache_llc_capacity_numa_2  \
# Time
# 1698040550000                        0.951705                        0.977273
# 1698040554000                        0.849432                        0.991477
# 1698040558000                        0.948864                        0.991477
# 1698040566000                        0.994318                        0.971591
# 1698040570000                        0.906250                        0.994318
# ...                                       ...                             ...
# 1698040690000                        0.960227                        0.974432
# 1698040694000                        0.914773                        1.005682
# 1698040698000                        0.940341                        0.982955
# 1698040702000                        0.917614                        1.005682
# 1698040706000                        0.951705                        0.980114
#
#                host_cache_llc_capacity_numa_3  host_kernel_context_switch  \
# Time
# 1698040550000                        0.988636                     87495.0
# 1698040554000                        0.982955                     88073.0
# 1698040558000                        0.980114                     90041.5
# 1698040566000                        0.988636                     88943.5
# 1698040570000                        0.963068                     95489.0
# ...                                       ...                         ...
# 1698040690000                        0.982955                     85645.5
# 1698040694000                        0.977273                     92706.5
# 1698040698000                        0.957386                     95659.5
# 1698040702000                        0.980114                     85944.0
# 1698040706000                        0.991477                     87596.0
#
#                host_kernel_interrupt  host_kernel_thread_fork_fork  \
# Time
# 1698040550000                83148.0                           0.0
# 1698040554000                82286.0                           0.0
# 1698040558000                84752.5                           0.0
# 1698040566000                83581.5                           0.0
# 1698040570000                89848.0                           0.0
# ...                              ...                           ...
# 1698040690000                82015.5                           0.0
# 1698040694000                88314.5                           0.0
# 1698040698000                89050.5                           0.0
# 1698040702000                83846.5                           0.0
# 1698040706000                83746.5                           0.0
#
#                host_kernel_syscall_accept  host_kernel_syscall_accept4  ...  \
# Time                                                                    ...
# 1698040550000                         0.5                          0.0  ...
# 1698040554000                         0.5                          0.0  ...
# 1698040558000                         0.5                          0.0  ...
# 1698040566000                         0.5                          0.0  ...
# 1698040570000                         0.5                          0.0  ...
# ...                                   ...                          ...  ...
# 1698040690000                         0.5                          0.0  ...
# 1698040694000                         1.0                          1.0  ...
# 1698040698000                         0.5                          0.0  ...
# 1698040702000                         0.5                          0.0  ...
# 1698040706000                         0.5                          0.0  ...
#
#                vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# Time
# 1698040550000                           0                         0.0
# 1698040554000                           0                         0.0
# 1698040558000                           0                         0.0
# 1698040566000                           0                         0.0
# 1698040570000                       16384                         3.5
# ...                                   ...                         ...
# 1698040690000                           0                         0.0
# 1698040694000                           0                         0.0
# 1698040698000                           0                         0.0
# 1698040702000                           0                         0.0
# 1698040706000                           0                         0.0
#
#                vm_block_io_time_write  \
# Time
# 1698040550000                0.000000
# 1698040554000                0.000000
# 1698040558000                0.000000
# 1698040566000                0.000000
# 1698040570000                0.003391
# ...                               ...
# 1698040690000                0.000000
# 1698040694000                0.000000
# 1698040698000                0.000000
# 1698040702000                0.000000
# 1698040706000                0.000000
#
#                vm_block_io_flush_request_and_time_request_vda  \
# Time
# 1698040550000                                               0
# 1698040554000                                               0
# 1698040558000                                               0
# 1698040566000                                               0
# 1698040570000                                               0
# ...                                                       ...
# 1698040690000                                               0
# 1698040694000                                               0
# 1698040698000                                               0
# 1698040702000                                               0
# 1698040706000                                               0
#
#                vm_block_io_flush_request_and_time_time_vda  \
# Time
# 1698040550000                                          0.0
# 1698040554000                                          0.0
# 1698040558000                                          0.0
# 1698040566000                                          0.0
# 1698040570000                                          0.0
# ...                                                    ...
# 1698040690000                                          0.0
# 1698040694000                                          0.0
# 1698040698000                                          0.0
# 1698040702000                                          0.0
# 1698040706000                                          0.0
#
#                app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# Time
# 1698040550000                         39507.5                          3951.5
# 1698040554000                         38915.0                          3892.5
# 1698040558000                         39919.0                          3991.0
# 1698040566000                         40468.0                          4046.5
# 1698040570000                         41526.5                          4152.5
# ...                                       ...                             ...
# 1698040690000                         39026.5                          3901.5
# 1698040694000                         39406.5                          3942.5
# 1698040698000                         40355.0                          4032.5
# 1698040702000                         40401.5                          4043.0
# 1698040706000                         39677.0                          3967.5
#
#                app_redis_qos_qps_of_redis_total  \
# Time
# 1698040550000                           43459.0
# 1698040554000                           42807.5
# 1698040558000                           43910.0
# 1698040566000                           44514.5
# 1698040570000                           45679.0
# ...                                         ...
# 1698040690000                           42928.0
# 1698040694000                           43349.0
# 1698040698000                           44387.5
# 1698040702000                           44444.5
# 1698040706000                           43644.5
#
#                app_redis_qos_p99_latency_set  app_redis_qos_p99_latency_get
# Time
# 1698040550000                           0.99                       0.990000
# 1698040554000                           0.99                       0.990012
# 1698040558000                           0.99                       0.990026
# 1698040566000                           0.99                       0.990000
# 1698040570000                           0.99                       0.990000
# ...                                      ...                            ...
# 1698040690000                           0.99                       0.990000
# 1698040694000                           0.99                       0.990000
# 1698040698000                           0.99                       0.990012
# 1698040702000                           0.99                       0.990000
# 1698040706000                           0.99                       0.990000
#
# [31 rows x 181 columns]

# %% [markdown]
# 或者通过 `agg_one_workload` 获取此 workload 对应时间序列下的均值

# %%
exp_data.agg_one_workload(workload_info)
# Out:
#    host_cache_llc_capacity_numa_0  host_cache_llc_capacity_numa_1  \
# 0                        0.969117                        0.932368
#
#    host_cache_llc_capacity_numa_2  host_cache_llc_capacity_numa_3  \
# 0                         0.98607                        0.977731
#
#    host_kernel_context_switch  host_kernel_interrupt  \
# 0                90670.274194           85881.451613
#
#    host_kernel_thread_fork_fork  host_kernel_syscall_accept  \
# 0                      0.112903                    0.564516
#
#    host_kernel_syscall_accept4  host_kernel_syscall_access  ...  \
# 0                     0.129032                  329.629032  ...
#
#    vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# 0                 1453.419355                    0.290323
#
#    vm_block_io_time_write  vm_block_io_flush_request_and_time_request_vda  \
# 0                0.000142                                        0.064516
#
#    vm_block_io_flush_request_and_time_time_vda  \
# 0                                     0.000014
#
#    app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# 0                    40144.822581                      4014.16129
#
#    app_redis_qos_qps_of_redis_total  app_redis_qos_p99_latency_set  \
# 0                      44158.983871                           0.99
#
#    app_redis_qos_p99_latency_get
# 0                       0.990009
#
# [1 rows x 180 columns]

# %% [markdown]
# `exp_data` 也允许只获取某个 干扰循环 的数据，通过下标指示

# %%
exp_data.agg_epoch(0)
# Out:
#          stress_cache  host_cache_llc_capacity_numa_0  \
# redis_0             1                        0.969117
# redis_1             1                        0.970935
# redis_2             1                        0.965691
# redis_3             1                        0.961199
# redis_4             1                        0.962216
# redis_5             1                        0.951246
# redis_6             1                        0.926948
# redis_7             1                        0.921632
# redis_8             1                        0.935498
#
#          host_cache_llc_capacity_numa_1  host_cache_llc_capacity_numa_2  \
# redis_0                        0.932368                        0.986070
# redis_1                        0.945950                        0.976326
# redis_2                        0.944784                        0.983974
# redis_3                        0.938023                        0.973161
# redis_4                        0.938068                        0.977273
# redis_5                        0.934751                        0.982771
# redis_6                        0.939448                        0.986932
# redis_7                        0.936045                        0.980252
# redis_8                        0.938985                        0.985408
#
#          host_cache_llc_capacity_numa_3  host_kernel_context_switch  \
# redis_0                        0.977731                90670.274194
# redis_1                        0.976399               114668.628205
# redis_2                        0.976471               132115.717949
# redis_3                        0.978843               130271.881579
# redis_4                        0.975142               126330.525000
# redis_5                        0.979747               111376.064516
# redis_6                        0.976705                80787.171429
# redis_7                        0.975055                48865.378049
# redis_8                        0.980695                37641.829545
#
#          host_kernel_interrupt  host_kernel_thread_fork_fork  \
# redis_0           85881.451613                      0.112903
# redis_1          117440.076923                      0.282051
# redis_2          115039.717949                      0.269231
# redis_3          110798.842105                      0.105263
# redis_4          103445.037500                      0.100000
# redis_5           68255.854839                      0.145161
# redis_6           61533.242857                      0.657143
# redis_7           45297.487805                      0.097561
# redis_8           36773.886364                      0.102273
#
#          host_kernel_syscall_accept  host_kernel_syscall_accept4  ...  \
# redis_0                    0.564516                     0.129032  ...
# redis_1                    0.576923                     0.128205  ...
# redis_2                    0.000000                     0.000000  ...
# redis_3                    0.526316                     0.052632  ...
# redis_4                    0.000000                     0.000000  ...
# redis_5                    0.516129                     0.032258  ...
# redis_6                    0.000000                     0.057143  ...
# redis_7                    0.000000                     0.000000  ...
# redis_8                    0.500011                     0.000000  ...
#
#          host_kernel_syscall_bpf  host_kernel_syscall_fgetxattr  \
# redis_0                 0.000000                       0.000000
# redis_1                 0.000000                       0.000000
# redis_2                 0.000000                       0.000000
# redis_3                 0.000000                       0.000000
# redis_4                 0.000000                       0.000000
# redis_5                 0.000000                       0.000000
# redis_6                 0.000000                       0.000000
# redis_7                 0.000000                       0.000000
# redis_8               368.508383                       4.500102
#
#          host_kernel_syscall_get_mempolicy  \
# redis_0                           0.000000
# redis_1                           0.000000
# redis_2                           0.000000
# redis_3                           0.000000
# redis_4                           0.000000
# redis_5                           0.000000
# redis_6                           0.000000
# redis_7                           0.000000
# redis_8                           1.000023
#
#          host_kernel_syscall_inotify_add_watch  host_kernel_syscall_mkdir  \
# redis_0                               0.000000                   0.000000
# redis_1                               0.000000                   0.000000
# redis_2                               0.000000                   0.000000
# redis_3                               0.000000                   0.000000
# redis_4                               0.000000                   0.000000
# redis_5                               0.000000                   0.000000
# redis_6                               0.000000                   0.000000
# redis_7                               0.000000                   0.000000
# redis_8                               2.000046                   0.500011
#
#          vm_hypervisor_emulator_syscall_count_ioctl  \
# redis_0                                    0.000000
# redis_1                                    0.000000
# redis_2                                    0.000000
# redis_3                                    0.000000
# redis_4                                    0.000000
# redis_5                                    0.000000
# redis_6                                    0.000000
# redis_7                                    0.000000
# redis_8                                    1.000023
#
#          vm_hypervisor_emulator_syscall_count_newfstatat  \
# redis_0                                          0.00000
# redis_1                                          0.00000
# redis_2                                          0.00000
# redis_3                                          0.00000
# redis_4                                          0.00000
# redis_5                                          0.00000
# redis_6                                          0.00000
# redis_7                                          0.00000
# redis_8                                          3.50008
#
#          vm_hypervisor_emulator_syscall_count_recvmsg  \
# redis_0                                      0.000000
# redis_1                                      0.000000
# redis_2                                      0.000000
# redis_3                                      0.000000
# redis_4                                      0.000000
# redis_5                                      0.000000
# redis_6                                      0.000000
# redis_7                                      0.000000
# redis_8                                    302.506882
#
#          vm_hypervisor_emulator_syscall_count_sendmsg  \
# redis_0                                      0.000000
# redis_1                                      0.000000
# redis_2                                      0.000000
# redis_3                                      0.000000
# redis_4                                      0.000000
# redis_5                                      0.000000
# redis_6                                      0.000000
# redis_7                                      0.000000
# redis_8                                      4.000091
#
#          vm_hypervisor_vcpu_syscall_count_write
# redis_0                                0.000000
# redis_1                                0.000000
# redis_2                                0.000000
# redis_3                                0.000000
# redis_4                                0.000000
# redis_5                                0.000000
# redis_6                                0.000000
# redis_7                                0.000000
# redis_8                                0.500011
#
# [9 rows x 243 columns]

# %% [markdown]
# ### 3. Advanced Usage
#
# 默认情况下 `exp_data` 对每个 workload 采用如下预处理手段，按顺序依次为:
# 1. `filter_column_startswith(col_prefix=("vm", "app"))`: 只选用 `vm`, `app` 前缀的指标
# 2. `filter_column_useless(std_min=1e-10)`: 过滤掉平均值为0, 或方差小于 `1e-10` 的指标
# 3. `filter_row_noise(col_prefix=("app"))`: 过滤行中 `app` 为前缀指标中的离群值
#
# 同时，对于每个 workload 采用如下聚合手段，按顺序依次为:
# 1. `lambda x : x.mean().to_frame().T`: 将一个workload时序数据按均值压缩为一行
#
# `exp_data` 允许对上述处理进行自定义, 需要注意的是, 自定义的方法设置完毕之后，将会一直生效，包括在 `agg_epoch` 时
# - `set_workload_preprocess_funcs(df_funcs):`: 自定义预处理手段
# - `set_workload_agg_funcs(df_funcs):`: 自定义聚合手段
#
# 其中 `df_funcs` 为一组函数，每个函数都满足如下签名:
# - `df_func(df: DataFrame) -> DataFrame`

# %%
exp_data.set_workload_preprocess_funcs([
    filter_column_startswith(col_prefix=("stress", "host", "vm", "app")),
    filter_column_useless(excol_prefix=("stress")),
])

exp_data.workload_df(workload_info, with_stress=True)
# Out:
#                stress_cache  host_cache_llc_capacity_numa_0  \
# Time
# 1698040546000             1                        0.968750
# 1698040550000             1                        0.980114
# 1698040554000             1                        0.974432
# 1698040558000             1                        0.957386
# 1698040562000             1                        0.971591
# ...                     ...                             ...
# 1698040690000             1                        0.965909
# 1698040694000             1                        0.982955
# 1698040698000             1                        0.957386
# 1698040702000             1                        0.965909
# 1698040706000             1                        0.954545
#
#                host_cache_llc_capacity_numa_1  host_cache_llc_capacity_numa_2  \
# Time
# 1698040546000                        0.963068                        0.968750
# 1698040550000                        0.951705                        0.977273
# 1698040554000                        0.849432                        0.991477
# 1698040558000                        0.948864                        0.991477
# 1698040562000                        0.838068                        0.965909
# ...                                       ...                             ...
# 1698040690000                        0.960227                        0.974432
# 1698040694000                        0.914773                        1.005682
# 1698040698000                        0.940341                        0.982955
# 1698040702000                        0.917614                        1.005682
# 1698040706000                        0.951705                        0.980114
#
#                host_cache_llc_capacity_numa_3  host_kernel_context_switch  \
# Time
# 1698040546000                        0.985795                    103930.0
# 1698040550000                        0.988636                     87495.0
# 1698040554000                        0.982955                     88073.0
# 1698040558000                        0.980114                     90041.5
# 1698040562000                        0.991477                     90490.0
# ...                                       ...                         ...
# 1698040690000                        0.982955                     85645.5
# 1698040694000                        0.977273                     92706.5
# 1698040698000                        0.957386                     95659.5
# 1698040702000                        0.980114                     85944.0
# 1698040706000                        0.991477                     87596.0
#
#                host_kernel_interrupt  host_kernel_thread_fork_fork  \
# Time
# 1698040546000                92411.0                           0.0
# 1698040550000                83148.0                           0.0
# 1698040554000                82286.0                           0.0
# 1698040558000                84752.5                           0.0
# 1698040562000                85934.5                           1.0
# ...                              ...                           ...
# 1698040690000                82015.5                           0.0
# 1698040694000                88314.5                           0.0
# 1698040698000                89050.5                           0.0
# 1698040702000                83846.5                           0.0
# 1698040706000                83746.5                           0.0
#
#                host_kernel_syscall_accept  host_kernel_syscall_accept4  ...  \
# Time                                                                    ...
# 1698040546000                         0.5                          0.0  ...
# 1698040550000                         0.5                          0.0  ...
# 1698040554000                         0.5                          0.0  ...
# 1698040558000                         0.5                          0.0  ...
# 1698040562000                         0.5                          0.0  ...
# ...                                   ...                          ...  ...
# 1698040690000                         0.5                          0.0  ...
# 1698040694000                         1.0                          1.0  ...
# 1698040698000                         0.5                          0.0  ...
# 1698040702000                         0.5                          0.0  ...
# 1698040706000                         0.5                          0.0  ...
#
#                vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# Time
# 1698040546000                        6144                         1.0
# 1698040550000                           0                         0.0
# 1698040554000                           0                         0.0
# 1698040558000                           0                         0.0
# 1698040562000                           0                         0.0
# ...                                   ...                         ...
# 1698040690000                           0                         0.0
# 1698040694000                           0                         0.0
# 1698040698000                           0                         0.0
# 1698040702000                           0                         0.0
# 1698040706000                           0                         0.0
#
#                vm_block_io_time_write  \
# Time
# 1698040546000                0.000171
# 1698040550000                0.000000
# 1698040554000                0.000000
# 1698040558000                0.000000
# 1698040562000                0.000000
# ...                               ...
# 1698040690000                0.000000
# 1698040694000                0.000000
# 1698040698000                0.000000
# 1698040702000                0.000000
# 1698040706000                0.000000
#
#                vm_block_io_flush_request_and_time_request_vda  \
# Time
# 1698040546000                                               1
# 1698040550000                                               0
# 1698040554000                                               0
# 1698040558000                                               0
# 1698040562000                                               0
# ...                                                       ...
# 1698040690000                                               0
# 1698040694000                                               0
# 1698040698000                                               0
# 1698040702000                                               0
# 1698040706000                                               0
#
#                vm_block_io_flush_request_and_time_time_vda  \
# Time
# 1698040546000                                     0.000246
# 1698040550000                                     0.000000
# 1698040554000                                     0.000000
# 1698040558000                                     0.000000
# 1698040562000                                     0.000000
# ...                                                    ...
# 1698040690000                                     0.000000
# 1698040694000                                     0.000000
# 1698040698000                                     0.000000
# 1698040702000                                     0.000000
# 1698040706000                                     0.000000
#
#                app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# Time
# 1698040546000                         95102.0                          9500.5
# 1698040550000                         39507.5                          3951.5
# 1698040554000                         38915.0                          3892.5
# 1698040558000                         39919.0                          3991.0
# 1698040562000                         40900.5                          4091.0
# ...                                       ...                             ...
# 1698040690000                         39026.5                          3901.5
# 1698040694000                         39406.5                          3942.5
# 1698040698000                         40355.0                          4032.5
# 1698040702000                         40401.5                          4043.0
# 1698040706000                         39677.0                          3967.5
#
#                app_redis_qos_qps_of_redis_total  \
# Time
# 1698040546000                          104602.5
# 1698040550000                           43459.0
# 1698040554000                           42807.5
# 1698040558000                           43910.0
# 1698040562000                           44991.5
# ...                                         ...
# 1698040690000                           42928.0
# 1698040694000                           43349.0
# 1698040698000                           44387.5
# 1698040702000                           44444.5
# 1698040706000                           43644.5
#
#                app_redis_qos_p99_latency_set  app_redis_qos_p99_latency_get
# Time
# 1698040546000                       2.512993                       2.515383
# 1698040550000                       0.990000                       0.990000
# 1698040554000                       0.990000                       0.990012
# 1698040558000                       0.990000                       0.990026
# 1698040562000                       0.990610                       0.990549
# ...                                      ...                            ...
# 1698040690000                       0.990000                       0.990000
# 1698040694000                       0.990000                       0.990000
# 1698040698000                       0.990000                       0.990012
# 1698040702000                       0.990000                       0.990000
# 1698040706000                       0.990000                       0.990000
#
# [41 rows x 181 columns]

# %%
# 获取最大值而不是平均值
exp_data.set_workload_agg_funcs([
    lambda x : x.max().to_frame().T,
])

exp_data.agg_one_workload(workload_info)
# Out:
#    host_cache_llc_capacity_numa_0  host_cache_llc_capacity_numa_1  \
# 0                        0.985795                        0.994318
#
#    host_cache_llc_capacity_numa_2  host_cache_llc_capacity_numa_3  \
# 0                        1.017045                             1.0
#
#    host_kernel_context_switch  host_kernel_interrupt  \
# 0                    103930.0                92411.0
#
#    host_kernel_thread_fork_fork  host_kernel_syscall_accept  \
# 0                           1.0                         1.0
#
#    host_kernel_syscall_accept4  host_kernel_syscall_access  ...  \
# 0                          1.0                       330.5  ...
#
#    vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# 0                    264192.0                         3.5
#
#    vm_block_io_time_write  vm_block_io_flush_request_and_time_request_vda  \
# 0                0.003391                                             2.0
#
#    vm_block_io_flush_request_and_time_time_vda  \
# 0                                     0.000512
#
#    app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# 0                         95102.0                          9500.5
#
#    app_redis_qos_qps_of_redis_total  app_redis_qos_p99_latency_set  \
# 0                          104602.5                       2.512993
#
#    app_redis_qos_p99_latency_get
# 0                       2.515383
#
# [1 rows x 180 columns]
