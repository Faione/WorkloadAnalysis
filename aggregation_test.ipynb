# %% [markdown]
# # Aggregation
#
# ## 场景一
#
# ### (1) 描述
#
# 场景一中，所有实验按固定的模式运行，包含干扰循环和负载循环
# 1. 初始化 client 和 server(vm)
# 2. 启动 background 干扰，当前支持的干扰有: cpu/cache/mem/io/net
# 3. 启动 workload， 当前支持的workload有: redis/nginx/mysql
# 4. workload 结束后，记录一份 `workload_info`, 包含时间戳, 负载、干扰强度等metadata
# 5. 回到步骤3，执行下一个workload，当所有workload都执行完毕后，记录一份 `info_per_epoch`, 包含所有已经执行的 `workload_info`, 以及此次循环的干扰强度信息
# 6. 回到步骤2，直到所有的强度的干扰都指向完毕
# 7. 结束实验，记录实验的启动、结束时间，总共消耗的时间，以及干扰循环的总次数
#
# 以上信息保存在 `exp.json` 或 `date.json` 中，另外通过 Prometheus client 请求得到整个实验周期中的metric数据，保存在 `merged.csv` 中

# %% [markdown]
# ### (2) 数据处理
#
#
# #### 1. Quick Start
#
#
# 通过 `read_from_dir(dir)` 读取 metadata 和csv 数据创建 `ExpData` 实例

# %%
from aggregation import *
pd.set_option('display.max_rows', 10) 

exp_root = "/home/ict/appProfile/data/addtion_exp/standard_stress_cache_20231023031422/"
exp_data = read_from_dir(exp_root)

# %% [markdown]
# 调用 `agg_epoch()` 方法之后，`exp_data` 会按每次干扰循环聚合数据, 这也是推荐的使用方法

# %%
df_epoch = exp_data.agg_epoch()
df_epoch
# Out:
#         cache  vm_hypervisor_emulator_syscall_count_clone3  \
# redis_0     1                                     0.026316
# redis_1     1                                     0.205128
# redis_2     1                                     0.200000
# redis_3     1                                     0.000000
# redis_4     1                                     0.250000
# ...       ...                                          ...
# redis_4    32                                     0.195122
# redis_5    32                                     0.121951
# redis_6    32                                     0.000000
# redis_7    32                                     0.200000
# redis_8    32                                     0.377822
#
#          vm_hypervisor_emulator_syscall_count_fdatasync  \
# redis_0                                        0.026316
# redis_1                                        0.102564
# redis_2                                        0.175000
# redis_3                                        0.052632
# redis_4                                        0.050000
# ...                                                 ...
# redis_4                                        0.121951
# redis_5                                        0.097561
# redis_6                                        0.050000
# redis_7                                        0.125000
# redis_8                                        0.133333
#
#          vm_hypervisor_emulator_syscall_count_futex_time64  \
# redis_0                                           0.736842
# redis_1                                           1.038462
# redis_2                                           1.325000
# redis_3                                           0.644737
# redis_4                                           0.525000
# ...                                                    ...
# redis_4                                           1.439024
# redis_5                                           0.865854
# redis_6                                           0.587500
# redis_7                                           0.725000
# redis_8                                           1.089078
#
#          vm_hypervisor_emulator_syscall_count_madvise  \
# redis_0                                      0.052632
# redis_1                                      0.192308
# redis_2                                      0.087500
# redis_3                                      0.000000
# redis_4                                      0.050000
# ...                                               ...
# redis_4                                      0.134146
# redis_5                                      0.036585
# redis_6                                      0.087500
# redis_7                                      0.150000
# redis_8                                      0.100000
#
#          vm_hypervisor_emulator_syscall_count_munmap  \
# redis_0                                     0.039474
# redis_1                                     0.076923
# redis_2                                     0.037500
# redis_3                                     0.000000
# redis_4                                     0.037500
# ...                                              ...
# redis_4                                     0.073171
# redis_5                                     0.000000
# redis_6                                     0.037500
# redis_7                                     0.075000
# redis_8                                     0.033333
#
#          vm_hypervisor_emulator_syscall_count_poll_time64  \
# redis_0                                        315.381579
# redis_1                                          0.000000
# redis_2                                        315.507895
# redis_3                                          0.000000
# redis_4                                          0.000000
# ...                                                   ...
# redis_4                                          0.000000
# redis_5                                        315.487805
# redis_6                                          0.000000
# redis_7                                          0.000000
# redis_8                                        315.507018
#
#          vm_hypervisor_emulator_syscall_count_ppoll_time64  \
# redis_0                                          18.921053
# redis_1                                          18.641026
# redis_2                                          18.575450
# redis_3                                          18.000000
# redis_4                                          18.312500
# ...                                                    ...
# redis_4                                          19.439024
# redis_5                                          19.219512
# redis_6                                          19.087500
# redis_7                                          20.437500
# redis_8                                          22.144934
#
#          vm_hypervisor_emulator_syscall_count_prctl  \
# redis_0                                    0.013158
# redis_1                                    0.102564
# redis_2                                    0.100000
# redis_3                                    0.000000
# redis_4                                    0.125000
# ...                                             ...
# redis_4                                    0.097561
# redis_5                                    0.060976
# redis_6                                    0.000000
# redis_7                                    0.100000
# redis_8                                    0.188911
#
#          vm_hypervisor_emulator_syscall_count_pwrite  ...  \
# redis_0                                     0.184211  ...
# redis_1                                     0.128205  ...
# redis_2                                     0.212500  ...
# redis_3                                     0.184211  ...
# redis_4                                     0.100000  ...
# ...                                              ...  ...
# redis_4                                     0.182927  ...
# redis_5                                     0.207317  ...
# redis_6                                     0.100000  ...
# redis_7                                     0.062500  ...
# redis_8                                     0.200067  ...
#
#          vm_mem_bandwidth_local_total_numa_1  \
# redis_0                             0.000000
# redis_1                             0.003005
# redis_2                             0.000000
# redis_3                             0.006168
# redis_4                             0.000000
# ...                                      ...
# redis_4                             0.066692
# redis_5                             0.000000
# redis_6                             0.000000
# redis_7                             0.000000
# redis_8                             0.000000
#
#          vm_mem_bandwidth_local_total_numa_3  \
# redis_0                             0.000000
# redis_1                             0.002003
# redis_2                             0.000000
# redis_3                             0.016447
# redis_4                             0.000000
# ...                                      ...
# redis_4                             0.000953
# redis_5                             0.024771
# redis_6                             0.011719
# redis_7                             0.003906
# redis_8                             0.026910
#
#          vm_hypervisor_emulator_syscall_count_newfstatat  \
# redis_0                                         0.000000
# redis_1                                         0.000000
# redis_2                                         3.500088
# redis_3                                         0.000000
# redis_4                                         0.000000
# ...                                                  ...
# redis_4                                         0.000000
# redis_5                                         0.000000
# redis_6                                         0.000000
# redis_7                                         0.000000
# redis_8                                         3.500078
#
#          vm_hypervisor_emulator_syscall_count_recvmsg  \
# redis_0                                      0.000000
# redis_1                                      0.000000
# redis_2                                    302.507570
# redis_3                                      0.000000
# redis_4                                      0.000000
# ...                                               ...
# redis_4                                      0.000000
# redis_5                                      0.000000
# redis_6                                      0.000000
# redis_7                                      0.000000
# redis_8                                    302.506729
#
#          vm_hypervisor_emulator_syscall_count_sendmsg  \
# redis_0                                      0.000000
# redis_1                                      0.000000
# redis_2                                      4.000100
# redis_3                                      0.000000
# redis_4                                      0.000000
# ...                                               ...
# redis_4                                      0.000000
# redis_5                                      0.000000
# redis_6                                      0.000000
# redis_7                                      0.000000
# redis_8                                      4.000089
#
#          vm_mem_bandwidth_local_local_numa_1  \
# redis_0                             0.000000
# redis_1                             0.000000
# redis_2                             0.000000
# redis_3                             0.002056
# redis_4                             0.000000
# ...                                      ...
# redis_4                             0.013338
# redis_5                             0.000000
# redis_6                             0.000000
# redis_7                             0.000000
# redis_8                             0.000000
#
#          vm_hypervisor_emulator_syscall_count_fallocate  \
# redis_0                                             0.0
# redis_1                                             0.0
# redis_2                                             0.0
# redis_3                                             0.0
# redis_4                                             0.0
# ...                                                 ...
# redis_4                                             0.0
# redis_5                                             0.0
# redis_6                                             0.0
# redis_7                                             0.0
# redis_8                                             0.0
#
#          vm_hypervisor_emulator_syscall_count_pread  \
# redis_0                                         0.0
# redis_1                                         0.0
# redis_2                                         0.0
# redis_3                                         0.0
# redis_4                                         0.0
# ...                                             ...
# redis_4                                         0.0
# redis_5                                         0.0
# redis_6                                         0.0
# redis_7                                         0.0
# redis_8                                         0.0
#
#          vm_block_io_sector_offset_offset_vda  \
# redis_0                                   0.0
# redis_1                                   0.0
# redis_2                                   0.0
# redis_3                                   0.0
# redis_4                                   0.0
# ...                                       ...
# redis_4                                   0.0
# redis_5                                   0.0
# redis_6                                   0.0
# redis_7                                   0.0
# redis_8                                   0.0
#
#          vm_hypervisor_emulator_syscall_duration_pread
# redis_0                                            0.0
# redis_1                                            0.0
# redis_2                                            0.0
# redis_3                                            0.0
# redis_4                                            0.0
# ...                                                ...
# redis_4                                            0.0
# redis_5                                            0.0
# redis_6                                            0.0
# redis_7                                            0.0
# redis_8                                            0.0
#
# [54 rows x 89 columns]

# %% [markdown]
# 因为返回的仍然是一个 DataFrame, 因此后续可以根据数据处理的需要自行设置方法，如下展示一种从 `df_epoch` 数据中获取某个 workload 数据的流程

# %%
df_epoch_group = df_epoch.groupby(df_epoch.index)
df_epoch_group.groups.keys()
# Out:
# dict_keys(['redis_0', 'redis_1', 'redis_2', 'redis_3', 'redis_4', 'redis_5', 'redis_6', 'redis_7', 'redis_8'])

# %% [markdown]
# 使用 `groupby` 函数处理 Dataframe, 并从 `groups.keys()` 选择一个获取此 workload 的数据

# %%
df_workload = df_epoch_group.get_group('redis_0')
df_workload
# Out:
#         cache  vm_hypervisor_emulator_syscall_count_clone3  \
# redis_0     1                                     0.026316
# redis_0     2                                     0.225806
# redis_0     4                                     0.368421
# redis_0     8                                     0.475000
# redis_0    16                                     0.128205
# redis_0    32                                     0.266667
#
#          vm_hypervisor_emulator_syscall_count_fdatasync  \
# redis_0                                        0.026316
# redis_0                                        0.064516
# redis_0                                        0.052632
# redis_0                                        0.100000
# redis_0                                        0.076923
# redis_0                                        0.133333
#
#          vm_hypervisor_emulator_syscall_count_futex_time64  \
# redis_0                                           0.736842
# redis_0                                           0.580645
# redis_0                                           0.736842
# redis_0                                           1.012500
# redis_0                                           0.807679
# redis_0                                           1.083333
#
#          vm_hypervisor_emulator_syscall_count_madvise  \
# redis_0                                      0.052632
# redis_0                                      0.129032
# redis_0                                      0.184211
# redis_0                                      0.237500
# redis_0                                      0.064090
# redis_0                                      0.200000
#
#          vm_hypervisor_emulator_syscall_count_munmap  \
# redis_0                                     0.039474
# redis_0                                     0.048387
# redis_0                                     0.078947
# redis_0                                     0.125000
# redis_0                                     0.000000
# redis_0                                     0.100000
#
#          vm_hypervisor_emulator_syscall_count_poll_time64  \
# redis_0                                        315.381579
# redis_0                                        315.467742
# redis_0                                          0.000000
# redis_0                                          0.000000
# redis_0                                        315.491918
# redis_0                                          0.000000
#
#          vm_hypervisor_emulator_syscall_count_ppoll_time64  \
# redis_0                                          18.921053
# redis_0                                          18.193548
# redis_0                                          18.276316
# redis_0                                          18.587500
# redis_0                                          18.127770
# redis_0                                          19.500000
#
#          vm_hypervisor_emulator_syscall_count_prctl  \
# redis_0                                    0.013158
# redis_0                                    0.112903
# redis_0                                    0.184211
# redis_0                                    0.237500
# redis_0                                    0.064103
# redis_0                                    0.133333
#
#          vm_hypervisor_emulator_syscall_count_pwrite  ...  \
# redis_0                                     0.184211  ...
# redis_0                                     0.032258  ...
# redis_0                                     0.184211  ...
# redis_0                                     0.225000  ...
# redis_0                                     0.217949  ...
# redis_0                                     0.083333  ...
#
#          vm_mem_bandwidth_local_total_numa_1  \
# redis_0                             0.000000
# redis_0                             0.000000
# redis_0                             0.023643
# redis_0                             0.020508
# redis_0                             0.244391
# redis_0                             0.000000
#
#          vm_mem_bandwidth_local_total_numa_3  \
# redis_0                             0.000000
# redis_0                             0.039062
# redis_0                             0.030839
# redis_0                             0.000000
# redis_0                             0.000000
# redis_0                             0.009115
#
#          vm_hypervisor_emulator_syscall_count_newfstatat  \
# redis_0                                          0.00000
# redis_0                                          0.00000
# redis_0                                          0.00000
# redis_0                                          0.00000
# redis_0                                          3.49991
# redis_0                                          0.00000
#
#          vm_hypervisor_emulator_syscall_count_recvmsg  \
# redis_0                                      0.000000
# redis_0                                      0.000000
# redis_0                                      0.000000
# redis_0                                      0.000000
# redis_0                                    302.492251
# redis_0                                      0.000000
#
#          vm_hypervisor_emulator_syscall_count_sendmsg  \
# redis_0                                      0.000000
# redis_0                                      0.000000
# redis_0                                      0.000000
# redis_0                                      0.000000
# redis_0                                      3.999898
# redis_0                                      0.000000
#
#          vm_mem_bandwidth_local_local_numa_1  \
# redis_0                             0.000000
# redis_0                             0.000000
# redis_0                             0.009252
# redis_0                             0.008789
# redis_0                             0.043069
# redis_0                             0.000000
#
#          vm_hypervisor_emulator_syscall_count_fallocate  \
# redis_0                                             0.0
# redis_0                                             0.0
# redis_0                                             0.0
# redis_0                                             0.0
# redis_0                                             0.0
# redis_0                                             0.0
#
#          vm_hypervisor_emulator_syscall_count_pread  \
# redis_0                                    0.000000
# redis_0                                    0.000000
# redis_0                                    0.000000
# redis_0                                    0.000000
# redis_0                                    0.012821
# redis_0                                    0.000000
#
#          vm_block_io_sector_offset_offset_vda  \
# redis_0                                   0.0
# redis_0                                   0.0
# redis_0                                   0.0
# redis_0                                   0.0
# redis_0                                   0.0
# redis_0                                   0.0
#
#          vm_hypervisor_emulator_syscall_duration_pread
# redis_0                                       0.000000
# redis_0                                       0.000000
# redis_0                                       0.000000
# redis_0                                       0.000000
# redis_0                                       2.589744
# redis_0                                       0.000000
#
# [6 rows x 89 columns]

# %% [markdown]
# #### 2. Custom Process
#
# `exp_data` 将读入的数据保存在 `exp` 与 `df` 两个字段中，可以通过 `exp_data.exp` 与 `exp_data.df` 来直接访问读入的数据， 如获取某个 workload info, 可以采取如下方式

# %%
workload_info = exp_data.exp["info_per_workload"]["redis_0"]["info_per_epoch"][0]
workload_info
# Out:
# {'start_time': 1698030875,
#  'run_cmd': 'docker exec -it redis-client-1 memtier_benchmark  -s envoy --test-time 160 -t 1',
#  'end_time': 1698031035,
#  'name': 'redis_0',
#  'addition': {'stress': {'cache': {'cache': '1'}}}}

# %% [markdown]
# 随后，可以使用” `workload_df` 来获取此 workload 对应的 dataframe

# %%
exp_data.workload_df(workload_info)
# Out:
#                vm_hypervisor_emulator_syscall_count_clone3  \
# Time
# 1698030882000                                          0.0
# 1698030886000                                          0.0
# 1698030890000                                          0.0
# 1698030894000                                          0.0
# 1698030898000                                          0.0
# ...                                                    ...
# 1698031014000                                          0.0
# 1698031018000                                          0.0
# 1698031022000                                          0.0
# 1698031030000                                          0.0
# 1698031034000                                          0.0
#
#                vm_hypervisor_emulator_syscall_count_fdatasync  \
# Time
# 1698030882000                                             0.0
# 1698030886000                                             0.0
# 1698030890000                                             0.0
# 1698030894000                                             0.0
# 1698030898000                                             0.0
# ...                                                       ...
# 1698031014000                                             0.0
# 1698031018000                                             0.0
# 1698031022000                                             0.0
# 1698031030000                                             0.0
# 1698031034000                                             0.0
#
#                vm_hypervisor_emulator_syscall_count_futex_time64  \
# Time
# 1698030882000                                                0.0
# 1698030886000                                                0.0
# 1698030890000                                                0.0
# 1698030894000                                                0.0
# 1698030898000                                                4.5
# ...                                                          ...
# 1698031014000                                                0.0
# 1698031018000                                                0.0
# 1698031022000                                                0.0
# 1698031030000                                                0.0
# 1698031034000                                                0.0
#
#                vm_hypervisor_emulator_syscall_count_madvise  \
# Time
# 1698030882000                                           0.0
# 1698030886000                                           0.0
# 1698030890000                                           0.0
# 1698030894000                                           0.0
# 1698030898000                                           2.0
# ...                                                     ...
# 1698031014000                                           0.0
# 1698031018000                                           0.0
# 1698031022000                                           0.0
# 1698031030000                                           0.0
# 1698031034000                                           0.0
#
#                vm_hypervisor_emulator_syscall_count_munmap  \
# Time
# 1698030882000                                          0.0
# 1698030886000                                          0.0
# 1698030890000                                          0.0
# 1698030894000                                          0.0
# 1698030898000                                          1.5
# ...                                                    ...
# 1698031014000                                          0.0
# 1698031018000                                          0.0
# 1698031022000                                          0.0
# 1698031030000                                          0.0
# 1698031034000                                          0.0
#
#                vm_hypervisor_emulator_syscall_count_poll_time64  \
# Time
# 1698030882000                                             315.5
# 1698030886000                                             315.5
# 1698030890000                                             315.5
# 1698030894000                                             315.0
# 1698030898000                                             315.5
# ...                                                         ...
# 1698031014000                                             315.0
# 1698031018000                                             315.5
# 1698031022000                                             315.5
# 1698031030000                                             315.5
# 1698031034000                                             315.0
#
#                vm_hypervisor_emulator_syscall_count_ppoll_time64  \
# Time
# 1698030882000                                               19.0
# 1698030886000                                               18.0
# 1698030890000                                               19.5
# 1698030894000                                               19.0
# 1698030898000                                               18.0
# ...                                                          ...
# 1698031014000                                               19.0
# 1698031018000                                               18.0
# 1698031022000                                               19.0
# 1698031030000                                               18.0
# 1698031034000                                               19.0
#
#                vm_hypervisor_emulator_syscall_count_prctl  \
# Time
# 1698030882000                                         0.0
# 1698030886000                                         0.0
# 1698030890000                                         0.0
# 1698030894000                                         0.0
# 1698030898000                                         0.0
# ...                                                   ...
# 1698031014000                                         0.0
# 1698031018000                                         0.0
# 1698031022000                                         0.0
# 1698031030000                                         0.0
# 1698031034000                                         0.0
#
#                vm_hypervisor_emulator_syscall_count_pwrite  \
# Time
# 1698030882000                                          0.0
# 1698030886000                                          0.0
# 1698030890000                                          0.0
# 1698030894000                                          0.0
# 1698030898000                                          0.0
# ...                                                    ...
# 1698031014000                                          0.0
# 1698031018000                                          0.0
# 1698031022000                                          0.0
# 1698031030000                                          0.0
# 1698031034000                                          0.0
#
#                vm_hypervisor_emulator_syscall_count_pwritev  ...  \
# Time                                                         ...
# 1698030882000                                           0.0  ...
# 1698030886000                                           0.0  ...
# 1698030890000                                           0.0  ...
# 1698030894000                                           0.0  ...
# 1698030898000                                           0.0  ...
# ...                                                     ...  ...
# 1698031014000                                           0.0  ...
# 1698031018000                                           0.0  ...
# 1698031022000                                           0.0  ...
# 1698031030000                                           0.0  ...
# 1698031034000                                           0.0  ...
#
#                vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# Time
# 1698030882000                         0.0                         0.0
# 1698030886000                         0.0                         0.0
# 1698030890000                      8192.0                         2.0
# 1698030894000                         0.0                         0.0
# 1698030898000                         0.0                         0.0
# ...                                   ...                         ...
# 1698031014000                         0.0                         0.0
# 1698031018000                         0.0                         0.0
# 1698031022000                         0.0                         0.0
# 1698031030000                         0.0                         0.0
# 1698031034000                         0.0                         0.0
#
#                vm_block_io_time_write  \
# Time
# 1698030882000                0.000000
# 1698030886000                0.000000
# 1698030890000                0.000377
# 1698030894000                0.000000
# 1698030898000                0.000000
# ...                               ...
# 1698031014000                0.000000
# 1698031018000                0.000000
# 1698031022000                0.000000
# 1698031030000                0.000000
# 1698031034000                0.000000
#
#                vm_block_io_flush_request_and_time_request_vda  \
# Time
# 1698030882000                                               0
# 1698030886000                                               0
# 1698030890000                                               0
# 1698030894000                                               0
# 1698030898000                                               0
# ...                                                       ...
# 1698031014000                                               0
# 1698031018000                                               0
# 1698031022000                                               0
# 1698031030000                                               0
# 1698031034000                                               0
#
#                vm_block_io_flush_request_and_time_time_vda  \
# Time
# 1698030882000                                          0.0
# 1698030886000                                          0.0
# 1698030890000                                          0.0
# 1698030894000                                          0.0
# 1698030898000                                          0.0
# ...                                                    ...
# 1698031014000                                          0.0
# 1698031018000                                          0.0
# 1698031022000                                          0.0
# 1698031030000                                          0.0
# 1698031034000                                          0.0
#
#                app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# Time
# 1698030882000                         39967.0                          3998.0
# 1698030886000                         40349.5                          4032.5
# 1698030890000                         40161.0                          4012.0
# 1698030894000                         39884.5                          3987.0
# 1698030898000                         39500.5                          3949.5
# ...                                       ...                             ...
# 1698031014000                         39371.5                          3938.5
# 1698031018000                         39217.0                          3923.0
# 1698031022000                         39373.0                          3935.5
# 1698031030000                         40052.0                          4004.5
# 1698031034000                         40048.5                          4006.0
#
#                app_redis_qos_qps_of_redis_total  \
# Time
# 1698030882000                           43965.0
# 1698030886000                           44382.0
# 1698030890000                           44173.0
# 1698030894000                           43871.5
# 1698030898000                           43450.0
# ...                                         ...
# 1698031014000                           43310.0
# 1698031018000                           43140.0
# 1698031022000                           43308.5
# 1698031030000                           44056.5
# 1698031034000                           44054.5
#
#                app_redis_qos_p99_latency_set  app_redis_qos_p99_latency_get
# Time
# 1698030882000                       0.990363                       0.990399
# 1698030886000                       0.990121                       0.990194
# 1698030890000                       0.990879                       0.990565
# 1698030894000                       0.991942                       0.990764
# 1698030898000                       0.990742                       0.990829
# ...                                      ...                            ...
# 1698031014000                       0.990000                       0.990000
# 1698031018000                       0.990000                       0.990000
# 1698031022000                       0.990250                       0.990626
# 1698031030000                       0.990502                       0.990891
# 1698031034000                       0.991240                       0.991004
#
# [38 rows x 68 columns]

# %% [markdown]
# 或者通过 `agg_one_workload` 获取此 workload 对应时间序列下的均值

# %%
exp_data.agg_one_workload(workload_info)
# Out:
#    vm_hypervisor_emulator_syscall_count_clone3  \
# 0                                     0.026316
#
#    vm_hypervisor_emulator_syscall_count_fdatasync  \
# 0                                        0.026316
#
#    vm_hypervisor_emulator_syscall_count_futex_time64  \
# 0                                           0.736842
#
#    vm_hypervisor_emulator_syscall_count_madvise  \
# 0                                      0.052632
#
#    vm_hypervisor_emulator_syscall_count_munmap  \
# 0                                     0.039474
#
#    vm_hypervisor_emulator_syscall_count_poll_time64  \
# 0                                        315.381579
#
#    vm_hypervisor_emulator_syscall_count_ppoll_time64  \
# 0                                          18.921053
#
#    vm_hypervisor_emulator_syscall_count_prctl  \
# 0                                    0.013158
#
#    vm_hypervisor_emulator_syscall_count_pwrite  \
# 0                                     0.184211
#
#    vm_hypervisor_emulator_syscall_count_pwritev  ...  \
# 0                                      0.039474  ...
#
#    vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# 0                      8192.0                    0.315789
#
#    vm_block_io_time_write  vm_block_io_flush_request_and_time_request_vda  \
# 0                0.000136                                        0.131579
#
#    vm_block_io_flush_request_and_time_time_vda  \
# 0                                     0.000034
#
#    app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# 0                    39671.368421                         3966.75
#
#    app_redis_qos_qps_of_redis_total  app_redis_qos_p99_latency_set  \
# 0                      43638.118421                       0.990426
#
#    app_redis_qos_p99_latency_get
# 0                       0.990417
#
# [1 rows x 68 columns]

# %% [markdown]
# `exp_data` 也允许只获取某个 干扰循环 的数据，通过下标指示

# %%
exp_data.agg_epoch(0)
# Out:
#         cache  vm_hypervisor_emulator_syscall_count_clone3  \
# redis_0     1                                     0.026316
# redis_1     1                                     0.205128
# redis_2     1                                     0.200000
# redis_3     1                                     0.000000
# redis_4     1                                     0.250000
# redis_5     1                                     0.218750
# redis_6     1                                     0.058824
# redis_7     1                                     0.184211
# redis_8     1                                     0.244444
#
#          vm_hypervisor_emulator_syscall_count_fdatasync  \
# redis_0                                        0.026316
# redis_1                                        0.102564
# redis_2                                        0.175000
# redis_3                                        0.052632
# redis_4                                        0.050000
# redis_5                                        0.062500
# redis_6                                        0.000000
# redis_7                                        0.078947
# redis_8                                        0.133333
#
#          vm_hypervisor_emulator_syscall_count_futex_time64  \
# redis_0                                           0.736842
# redis_1                                           1.038462
# redis_2                                           1.325000
# redis_3                                           0.644737
# redis_4                                           0.525000
# redis_5                                           0.578125
# redis_6                                           0.632353
# redis_7                                           0.907895
# redis_8                                           0.922222
#
#          vm_hypervisor_emulator_syscall_count_madvise  \
# redis_0                                      0.052632
# redis_1                                      0.192308
# redis_2                                      0.087500
# redis_3                                      0.000000
# redis_4                                      0.050000
# redis_5                                      0.015625
# redis_6                                      0.102941
# redis_7                                      0.171053
# redis_8                                      0.100000
#
#          vm_hypervisor_emulator_syscall_count_munmap  \
# redis_0                                     0.039474
# redis_1                                     0.076923
# redis_2                                     0.037500
# redis_3                                     0.000000
# redis_4                                     0.037500
# redis_5                                     0.000000
# redis_6                                     0.000000
# redis_7                                     0.039474
# redis_8                                     0.033333
#
#          vm_hypervisor_emulator_syscall_count_poll_time64  \
# redis_0                                        315.381579
# redis_1                                          0.000000
# redis_2                                        315.507895
# redis_3                                          0.000000
# redis_4                                          0.000000
# redis_5                                          0.000000
# redis_6                                          0.000000
# redis_7                                        315.486842
# redis_8                                          0.000000
#
#          vm_hypervisor_emulator_syscall_count_ppoll_time64  \
# redis_0                                          18.921053
# redis_1                                          18.641026
# redis_2                                          18.575450
# redis_3                                          18.000000
# redis_4                                          18.312500
# redis_5                                          18.531250
# redis_6                                          17.897059
# redis_7                                          18.407895
# redis_8                                          18.955556
#
#          vm_hypervisor_emulator_syscall_count_prctl  \
# redis_0                                    0.013158
# redis_1                                    0.102564
# redis_2                                    0.100000
# redis_3                                    0.000000
# redis_4                                    0.125000
# redis_5                                    0.109375
# redis_6                                    0.029412
# redis_7                                    0.092105
# redis_8                                    0.122222
#
#          vm_hypervisor_emulator_syscall_count_pwrite  ...  \
# redis_0                                     0.184211  ...
# redis_1                                     0.128205  ...
# redis_2                                     0.212500  ...
# redis_3                                     0.184211  ...
# redis_4                                     0.100000  ...
# redis_5                                     0.093750  ...
# redis_6                                     0.161765  ...
# redis_7                                     0.171053  ...
# redis_8                                     0.133333  ...
#
#          vm_hypervisor_vcpu_syscall_count_write  \
# redis_0                                0.000000
# redis_1                                0.166667
# redis_2                                0.000000
# redis_3                                0.000000
# redis_4                                0.000000
# redis_5                                0.000000
# redis_6                                0.000000
# redis_7                                0.000000
# redis_8                                0.000000
#
#          vm_hypervisor_vcpu_syscall_duration_futex_time64  \
# redis_0                                          0.000000
# redis_1                                          5.403846
# redis_2                                          2.275000
# redis_3                                          3.197368
# redis_4                                          0.000000
# redis_5                                          0.484375
# redis_6                                          0.566176
# redis_7                                          5.046053
# redis_8                                          4.672222
#
#          vm_cache_last-level_cache_capacity_vm_occupancy_numa_1  \
# redis_0                                           0.000000
# redis_1                                           0.000073
# redis_2                                           0.000000
# redis_3                                           0.007102
# redis_4                                           0.000284
# redis_5                                           0.000000
# redis_6                                           0.002757
# redis_7                                           0.000374
# redis_8                                           0.000000
#
#          vm_mem_bandwidth_local_local_numa_3  \
# redis_0                             0.000000
# redis_1                             0.000000
# redis_2                             0.000000
# redis_3                             0.012336
# redis_4                             0.000000
# redis_5                             0.001221
# redis_6                             0.002298
# redis_7                             0.010280
# redis_8                             0.000000
#
#          vm_mem_bandwidth_local_total_numa_1  \
# redis_0                             0.000000
# redis_1                             0.003005
# redis_2                             0.000000
# redis_3                             0.006168
# redis_4                             0.000000
# redis_5                             0.000000
# redis_6                             0.011489
# redis_7                             0.000000
# redis_8                             0.000000
#
#          vm_mem_bandwidth_local_total_numa_3  \
# redis_0                             0.000000
# redis_1                             0.002003
# redis_2                             0.000000
# redis_3                             0.016447
# redis_4                             0.000000
# redis_5                             0.004883
# redis_6                             0.020680
# redis_7                             0.016447
# redis_8                             0.001736
#
#          vm_hypervisor_emulator_syscall_count_newfstatat  \
# redis_0                                         0.000000
# redis_1                                         0.000000
# redis_2                                         3.500088
# redis_3                                         0.000000
# redis_4                                         0.000000
# redis_5                                         0.000000
# redis_6                                         0.000000
# redis_7                                         0.000000
# redis_8                                         0.000000
#
#          vm_hypervisor_emulator_syscall_count_recvmsg  \
# redis_0                                       0.00000
# redis_1                                       0.00000
# redis_2                                     302.50757
# redis_3                                       0.00000
# redis_4                                       0.00000
# redis_5                                       0.00000
# redis_6                                       0.00000
# redis_7                                       0.00000
# redis_8                                       0.00000
#
#          vm_hypervisor_emulator_syscall_count_sendmsg  \
# redis_0                                        0.0000
# redis_1                                        0.0000
# redis_2                                        4.0001
# redis_3                                        0.0000
# redis_4                                        0.0000
# redis_5                                        0.0000
# redis_6                                        0.0000
# redis_7                                        0.0000
# redis_8                                        0.0000
#
#          vm_mem_bandwidth_local_local_numa_1
# redis_0                             0.000000
# redis_1                             0.000000
# redis_2                             0.000000
# redis_3                             0.002056
# redis_4                             0.000000
# redis_5                             0.000000
# redis_6                             0.004596
# redis_7                             0.000000
# redis_8                             0.000000
#
# [9 rows x 85 columns]

# %% [markdown]
# 3. Advanced Usage
#
# 默认情况下 `exp_data` 对每个 workload 采用如下预处理手段，按顺序依次为:
# 1. `filter_column_startswith(col_prefix=("vm", "app"))`: 只选用 `vm`, `app` 前缀的指标
# 2. `filter_column_useless(std_min=1e-10)`: 过滤掉平均值为0, 或方差小于 `1e-10` 的指标
# 3. `filter_row_noise(col_prefix=("app"))`: 过滤行中 `app` 为前缀指标中的离群值
#
# 同时，对于每个 workload 采用如下聚合手段，按顺序依次为:
# 1. `lambda x : x.mean().to_frame().T`: 将一个workload时序数据按均值压缩为一行
#
# `exp_data` 允许对上述处理进行自定义, 需要注意的是, 自定义的方法设置完毕之后，将会一直生效，包括在 `agg_epoch` 时
# - `set_workload_preprocess_funcs(df_funcs):`: 自定义预处理手段
# - `set_workload_agg_funcs(df_funcs):`: 自定义聚合手段
#
# 其中 `df_funcs` 为一组函数，每个函数都满足如下签名:
# - `df_func(df: DataFrame) -> DataFrame`

# %%
exp_data.set_workload_preprocess_funcs([
    filter_column_startswith(col_prefix=("vm", "app")),
    filter_column_useless(std_min=1e-10),
])

exp_data.workload_df(workload_info)
# Out:
#                vm_hypervisor_emulator_syscall_count_clone3  \
# Time
# 1698030878000                                          0.0
# 1698030882000                                          0.0
# 1698030886000                                          0.0
# 1698030890000                                          0.0
# 1698030894000                                          0.0
# ...                                                    ...
# 1698031018000                                          0.0
# 1698031022000                                          0.0
# 1698031026000                                          0.0
# 1698031030000                                          0.0
# 1698031034000                                          0.0
#
#                vm_hypervisor_emulator_syscall_count_fdatasync  \
# Time
# 1698030878000                                             0.0
# 1698030882000                                             0.0
# 1698030886000                                             0.0
# 1698030890000                                             0.0
# 1698030894000                                             0.0
# ...                                                       ...
# 1698031018000                                             0.0
# 1698031022000                                             0.0
# 1698031026000                                             0.0
# 1698031030000                                             0.0
# 1698031034000                                             0.0
#
#                vm_hypervisor_emulator_syscall_count_futex_time64  \
# Time
# 1698030878000                                                8.5
# 1698030882000                                                0.0
# 1698030886000                                                0.0
# 1698030890000                                                0.0
# 1698030894000                                                0.0
# ...                                                          ...
# 1698031018000                                                0.0
# 1698031022000                                                0.0
# 1698031026000                                                0.0
# 1698031030000                                                0.0
# 1698031034000                                                0.0
#
#                vm_hypervisor_emulator_syscall_count_madvise  \
# Time
# 1698030878000                                           0.0
# 1698030882000                                           0.0
# 1698030886000                                           0.0
# 1698030890000                                           0.0
# 1698030894000                                           0.0
# ...                                                     ...
# 1698031018000                                           0.0
# 1698031022000                                           0.0
# 1698031026000                                           0.0
# 1698031030000                                           0.0
# 1698031034000                                           0.0
#
#                vm_hypervisor_emulator_syscall_count_munmap  \
# Time
# 1698030878000                                          0.0
# 1698030882000                                          0.0
# 1698030886000                                          0.0
# 1698030890000                                          0.0
# 1698030894000                                          0.0
# ...                                                    ...
# 1698031018000                                          0.0
# 1698031022000                                          0.0
# 1698031026000                                          0.0
# 1698031030000                                          0.0
# 1698031034000                                          0.0
#
#                vm_hypervisor_emulator_syscall_count_poll_time64  \
# Time
# 1698030878000                                             315.5
# 1698030882000                                             315.5
# 1698030886000                                             315.5
# 1698030890000                                             315.5
# 1698030894000                                             315.0
# ...                                                         ...
# 1698031018000                                             315.5
# 1698031022000                                             315.5
# 1698031026000                                             315.5
# 1698031030000                                             315.5
# 1698031034000                                             315.0
#
#                vm_hypervisor_emulator_syscall_count_ppoll_time64  \
# Time
# 1698030878000                                               20.5
# 1698030882000                                               19.0
# 1698030886000                                               18.0
# 1698030890000                                               19.5
# 1698030894000                                               19.0
# ...                                                          ...
# 1698031018000                                               18.0
# 1698031022000                                               19.0
# 1698031026000                                               19.0
# 1698031030000                                               18.0
# 1698031034000                                               19.0
#
#                vm_hypervisor_emulator_syscall_count_prctl  \
# Time
# 1698030878000                                         0.0
# 1698030882000                                         0.0
# 1698030886000                                         0.0
# 1698030890000                                         0.0
# 1698030894000                                         0.0
# ...                                                   ...
# 1698031018000                                         0.0
# 1698031022000                                         0.0
# 1698031026000                                         0.0
# 1698031030000                                         0.0
# 1698031034000                                         0.0
#
#                vm_hypervisor_emulator_syscall_count_pwrite  \
# Time
# 1698030878000                                          3.0
# 1698030882000                                          0.0
# 1698030886000                                          0.0
# 1698030890000                                          0.0
# 1698030894000                                          0.0
# ...                                                    ...
# 1698031018000                                          0.0
# 1698031022000                                          0.0
# 1698031026000                                          0.0
# 1698031030000                                          0.0
# 1698031034000                                          0.0
#
#                vm_hypervisor_emulator_syscall_count_pwritev  ...  \
# Time                                                         ...
# 1698030878000                                           0.5  ...
# 1698030882000                                           0.0  ...
# 1698030886000                                           0.0  ...
# 1698030890000                                           0.0  ...
# 1698030894000                                           0.0  ...
# ...                                                     ...  ...
# 1698031018000                                           0.0  ...
# 1698031022000                                           0.0  ...
# 1698031026000                                           0.0  ...
# 1698031030000                                           0.0  ...
# 1698031034000                                           0.0  ...
#
#                vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# Time
# 1698030878000                     16384.0                         3.5
# 1698030882000                         0.0                         0.0
# 1698030886000                         0.0                         0.0
# 1698030890000                      8192.0                         2.0
# 1698030894000                         0.0                         0.0
# ...                                   ...                         ...
# 1698031018000                         0.0                         0.0
# 1698031022000                         0.0                         0.0
# 1698031026000                         0.0                         0.0
# 1698031030000                         0.0                         0.0
# 1698031034000                         0.0                         0.0
#
#                vm_block_io_time_write  \
# Time
# 1698030878000                0.000600
# 1698030882000                0.000000
# 1698030886000                0.000000
# 1698030890000                0.000377
# 1698030894000                0.000000
# ...                               ...
# 1698031018000                0.000000
# 1698031022000                0.000000
# 1698031026000                0.000000
# 1698031030000                0.000000
# 1698031034000                0.000000
#
#                vm_block_io_flush_request_and_time_request_vda  \
# Time
# 1698030878000                                               0
# 1698030882000                                               0
# 1698030886000                                               0
# 1698030890000                                               0
# 1698030894000                                               0
# ...                                                       ...
# 1698031018000                                               0
# 1698031022000                                               0
# 1698031026000                                               0
# 1698031030000                                               0
# 1698031034000                                               0
#
#                vm_block_io_flush_request_and_time_time_vda  \
# Time
# 1698030878000                                          0.0
# 1698030882000                                          0.0
# 1698030886000                                          0.0
# 1698030890000                                          0.0
# 1698030894000                                          0.0
# ...                                                    ...
# 1698031018000                                          0.0
# 1698031022000                                          0.0
# 1698031026000                                          0.0
# 1698031030000                                          0.0
# 1698031034000                                          0.0
#
#                app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# Time
# 1698030878000                         39840.0                          3985.0
# 1698030882000                         39967.0                          3998.0
# 1698030886000                         40349.5                          4032.5
# 1698030890000                         40161.0                          4012.0
# 1698030894000                         39884.5                          3987.0
# ...                                       ...                             ...
# 1698031018000                         39217.0                          3923.0
# 1698031022000                         39373.0                          3935.5
# 1698031026000                         39322.5                          3934.0
# 1698031030000                         40052.0                          4004.5
# 1698031034000                         40048.5                          4006.0
#
#                app_redis_qos_qps_of_redis_total  \
# Time
# 1698030878000                           43825.0
# 1698030882000                           43965.0
# 1698030886000                           44382.0
# 1698030890000                           44173.0
# 1698030894000                           43871.5
# ...                                         ...
# 1698031018000                           43140.0
# 1698031022000                           43308.5
# 1698031026000                           43256.5
# 1698031030000                           44056.5
# 1698031034000                           44054.5
#
#                app_redis_qos_p99_latency_set  app_redis_qos_p99_latency_get
# Time
# 1698030878000                       2.452920                       2.474957
# 1698030882000                       0.990363                       0.990399
# 1698030886000                       0.990121                       0.990194
# 1698030890000                       0.990879                       0.990565
# 1698030894000                       0.991942                       0.990764
# ...                                      ...                            ...
# 1698031018000                       0.990000                       0.990000
# 1698031022000                       0.990250                       0.990626
# 1698031026000                       0.991919                       0.991920
# 1698031030000                       0.990502                       0.990891
# 1698031034000                       0.991240                       0.991004
#
# [40 rows x 68 columns]

# %%
# 获取最大值而不是平均值
exp_data.set_workload_agg_funcs([
    lambda x : x.max().to_frame().T,
])

exp_data.agg_one_workload(workload_info)
# Out:
#    vm_hypervisor_emulator_syscall_count_clone3  \
# 0                                          1.0
#
#    vm_hypervisor_emulator_syscall_count_fdatasync  \
# 0                                             1.0
#
#    vm_hypervisor_emulator_syscall_count_futex_time64  \
# 0                                               12.0
#
#    vm_hypervisor_emulator_syscall_count_madvise  \
# 0                                           2.0
#
#    vm_hypervisor_emulator_syscall_count_munmap  \
# 0                                          1.5
#
#    vm_hypervisor_emulator_syscall_count_poll_time64  \
# 0                                             315.5
#
#    vm_hypervisor_emulator_syscall_count_ppoll_time64  \
# 0                                               22.0
#
#    vm_hypervisor_emulator_syscall_count_prctl  \
# 0                                         0.5
#
#    vm_hypervisor_emulator_syscall_count_pwrite  \
# 0                                          3.0
#
#    vm_hypervisor_emulator_syscall_count_pwritev  ...  \
# 0                                           0.5  ...
#
#    vm_block_io_bytes_io_write  vm_block_io_requests_write  \
# 0                    264192.0                         3.5
#
#    vm_block_io_time_write  vm_block_io_flush_request_and_time_request_vda  \
# 0                0.002691                                             2.0
#
#    vm_block_io_flush_request_and_time_time_vda  \
# 0                                     0.000653
#
#    app_redis_qos_qps_of_redis_get  app_redis_qos_qps_of_redis_set  \
# 0                         40989.5                          4101.5
#
#    app_redis_qos_qps_of_redis_total  app_redis_qos_p99_latency_set  \
# 0                           45091.0                        2.45292
#
#    app_redis_qos_p99_latency_get
# 0                       2.474957
#
# [1 rows x 68 columns]
