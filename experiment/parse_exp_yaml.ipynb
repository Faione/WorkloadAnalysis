# %%
import os
import json
import pandas as pd

import sys
sys.path.append('./tools/experiment')
sys.path.append('./tools/client')

import experiment
import executor
import generator

import prometheus
import grafana
import config_parser

import yaml
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)


# yaml range to range
def yrange_to_range(yrange):
    if "start" in yrange and "end" in yrange and "step" in yrange:
        return range(yrange["start"], yrange["end"], yrange["step"])
    return yrange

def exp_from_yaml(data):
    exp = experiment.Experiment(**data["raw"])

    if "settings" in data:
        settings = data["settings"]
        if "stress" in settings:
            stress = settings["stress"]
            if "cpu" in stress:
                cpu = stress["cpu"]
                exp.with_cpu_stress(
                    cpu_range = yrange_to_range(cpu["cpu_range"]),
                    cpuload_range = yrange_to_range(cpu["cpuload_range"]),
                )
            if "mem" in stress:
                mem = stress["mem"]
                exp.with_mem_stress(
                    memrate_range = yrange_to_range(mem["memrate_range"]),
                    memrate_byte = mem["memrate_byte"],
                )
    
    return exp

def workload_from_yaml(data):
    workload = generator.Workload(**data["raw"])
    for flag, value in data["flags"].items():
        if flag == "-t":
            workload.with_flag(
                flag, yrange_to_range(value)
            )
        else:
            workload.with_flag(flag, [value])
            
    return workload
    
def workload_exec_from_yaml(data):
    return executor.WorkloadExecutor(**data["raw"])

def stress_exec_from_yaml(data):
    return executor.StressExecutor(**data["raw"])


with open("experiment.yaml", 'r') as f:
    file_data = f.read()

DEFAULT_OPT_INTERVAL = 60

cfg = yaml.load(file_data, yaml.FullLoader)
if "default_opt_interval" in cfg:
    DEFAULT_OPT_INTERVAL = cfg["default_opt_interval"]

workload = workload_from_yaml(cfg["workload"])
cfg["workload_exec"]["raw"]["run_cmd"] = workload.build()

if "opt_interval" not in cfg["workload_exec"]:
    cfg["workload_exec"]["raw"]["opt_interval"] = DEFAULT_OPT_INTERVAL

if "opt_interval" not in cfg["stress_exec"]:
    cfg["stress_exec"]["raw"]["opt_interval"] = DEFAULT_OPT_INTERVAL

# %%
exp = exp_from_yaml(cfg["experiment"])
workload_exec = workload_exec_from_yaml(cfg["workload_exec"])
stress_exec = stress_exec_from_yaml(cfg["stress_exec"])

# %%
exp.run(stress_exec=stress_exec, workload_exec=workload_exec, interval=DEFAULT_OPT_INTERVAL)
# Out:
# INFO:root:1696940702 experiment start
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 1 --cpu-load 25
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 1 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 1 --cpu-load 50
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 2 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 1 --cpu-load 75
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 3 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 1 --cpu-load 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 4 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 2 --cpu-load 25
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 5 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 2 --cpu-load 50
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 6 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 2 --cpu-load 75
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 7 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 2 --cpu-load 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 8 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 3 --cpu-load 25
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 9 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 3 --cpu-load 50
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 10 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 3 --cpu-load 75
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 11 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 3 --cpu-load 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 12 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 4 --cpu-load 25
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 13 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 4 --cpu-load 50
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 14 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 4 --cpu-load 75
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 15 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_cpu --cpuset-cpus 120-123 localhost/my-stress-ng:v0.1 --cpu 4 --cpu-load 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman run -d --rm --name stress_mem --cpuset-cpus 40-43 localhost/my-stress-ng:v0.1 --memrate 16 --memrate-bytes 1G
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 25
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 50
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 75
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 10
# INFO:root:run: docker exec -it redis-client-1 memtier_benchmark -s envoy --test-time 180 -t 100
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_cpu
# INFO:root:run: ssh fhl@worknode-01 sudo podman stop stress_mem

# %%
# data_root = cfg["data_root"]

# dir_path = os.path.join(data_root, exp.dir_name())
# if not os.path.exists(dir_path):
#     os.mkdir(dir_path)

# with open(os.path.join(dir_path, cfg["experiment"]["save_file"]), 'w') as f:
#     json.dump(exp.__dict__, f)

# with open(os.path.join(dir_path, cfg["workload_exec"]["save_file"]), 'w') as f:
#     json.dump(workload_exec.info_per_workload, f)

# %%
## Collet Data
grafana_auth = cfg["collect"]["grafana"]["auth"]
grafana_server = cfg["collect"]["grafana"]["server"]
prom_server = cfg["collect"]["prometheus"]["server"]
aio_db = cfg["collect"]["query"]["dashboard"]
step = cfg["collect"]["query"]["step"]
dash_boards = cfg["collect"]["query"]["dashboard"]

pclient = prometheus.client(prom_server)
gclient = grafana.client(grafana_server, grafana_auth)

db_datas = [gclient.get_db(db) for db in dash_boards]
assert len(db_datas) > 0, "no prometheus data collect"

if "aio" in dash_boards:
    logging.warning("while aio dashboard is existing, only fetching aio data")
    dash_boards = ["aio"]

targets = []
if len(dash_boards) == 1 and dash_boards[0] == "aio":
    # assert it is aio
    targets = db_datas[0]["panels"][0]["targets"]
else:
    for db_data in db_datas:
        targets = targets + config_parser.read_targets_from_json(db_data)

df = pclient.targets_to_df(targets, exp.start_time, exp.end_time, step)
print(df.info())
df.to_csv(os.path.join(dir_path, cfg["collect"]["save_file"]))
# Out:
# [{'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'resctrl_llc_occupancy_bytes{group="global", job="resctrl_exporter", instance="worknode:9900"} / 1024 / 28160',
#   'legendFormat': 'host_cache_llc_capacity_numa_{{numa}}',
#   'range': True,
#   'refId': 'BwVwT'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'rate(node_context_switches_total{instance="worknode:9100", job="node_exporter"}[$__interval])',
#   'legendFormat': 'host_kernel_context_switch',
#   'range': True,
#   'refId': 'hBzb0'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'rate(node_intr_total{instance="worknode:9100", job="node_exporter"}[$__interval])',
#   'legendFormat': 'host_kernel_interrupt',
#   'range': True,
#   'refId': 'g3mIy'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'rate(node_forks_total{instance="worknode:9100",job="node_exporter"}[$__interval])',
#   'legendFormat': 'host_kernel_thread_fork_fork',
#   'range': True,
#   'refId': 'zlNkP'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'irate(ebpf_exporter_syscalls_total{job="ebpf_exporter", instance="worknode:9435"}[$__interval])',
#   'legendFormat': 'host_kernel_syscall_{{syscall}}',
#   'range': True,
#   'refId': 'sW7rV'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'avg by(mode)(rate(node_cpu_seconds_total{instance="worknode:9100",job="node_exporter"}[$__interval]))',
#   'legendFormat': 'host_cpu_usage_{{mode}}',
#   'range': True,
#   'refId': 'rP4nY'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'node_cpu_scaling_frequency_hertz{instance="worknode:9100", job="node_exporter", cpu="131"} / 1000 / 1000',
#   'legendFormat': 'host_cpu_scaling_freq_mhz_cpu131',
#   'range': True,
#   'refId': 'K055X'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'avg(node_cpu_scaling_frequency_hertz) / 1000 / 1000',
#   'hide': False,
#   'legendFormat': 'host_cpu_scaling_freq_mhz_avg',
#   'range': True,
#   'refId': 'O3btm'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'node_load5 / on (instance) (count by (instance) (node_cpu_seconds_total{mode="idle",instance="worknode:9100",job="node_exporter"}))',
#   'legendFormat': 'host_cpu_cpu__load_per_cores_load5',
#   'range': True,
#   'refId': 'TYhz0'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'node_load1 / on (instance) (count by (instance) (node_cpu_seconds_total{mode="idle",instance="worknode:9100",job="node_exporter"}))',
#   'hide': False,
#   'legendFormat': 'host_cpu_cpu__load_per_cores_load1',
#   'range': True,
#   'refId': 'pobK8'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'node_load15 / on (instance) (count by (instance) (node_cpu_seconds_total{mode="idle",instance="worknode:9100",job="node_exporter"}))',
#   'hide': False,
#   'legendFormat': 'host_cpu_cpu__load_per_cores_load15',
#   'range': True,
#   'refId': 'paWFe'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': '100 * (1- (node_memory_MemFree_bytes{instance="worknode:9100", job="node_exporter"}\r\n + node_memory_Buffers_bytes{instance="worknode:9100", job="node_exporter"}\r\n + node_memory_Cached_bytes{instance="worknode:9100", job="node_exporter"}) \r\n / node_memory_MemTotal_bytes{instance="worknode:9100", job="node_exporter"})',
#   'legendFormat': 'host_memory_usage_not_contain_cache_and_buffer_not_contain_cache_and_buffer',
#   'range': True,
#   'refId': 'NFE38'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': '100 * (1-(node_memory_MemFree_bytes{instance="worknode:9100", job="node_exporter"}) \r\n / node_memory_MemTotal_bytes{instance="worknode:9100", job="node_exporter"})',
#   'legendFormat': 'host_memory_usage_contain_cache_and_buffer_contain_cache_and_buffer',
#   'range': True,
#   'refId': 'KbWa2'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'rate(resctrl_mem_bandwidth_local_bytes{group="global", job="resctrl_exporter", instance="worknode:9900"}[$__interval]) / 1024 / 1024',
#   'legendFormat': 'host_memory_mem_bandwidth_local_numa_{{numa}}',
#   'range': True,
#   'refId': 'N7i57'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'rate(resctrl_mem_bandwidth_total_bytes{group="global", job="resctrl_exporter", instance="worknode:9900"}[$__interval]) / 1024 / 1024',
#   'hide': False,
#   'legendFormat': 'host_memory_mem_bandwidth_total_numa_{{numa}}',
#   'range': True,
#   'refId': 'Itn2f'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(node_network_receive_bytes_total{device=~"enp26s0f.*", instance="worknode:9100", job="node_exporter"}[$__interval]))',
#   'legendFormat': 'host_network_io_bytes_receive',
#   'range': True,
#   'refId': 'u4FNv'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(node_network_transmit_bytes_total{device=~"enp26s0f.*", instance="worknode:9100", job="node_exporter"}[$__interval]))',
#   'hide': False,
#   'legendFormat': 'host_network_io_bytes_transmit',
#   'range': True,
#   'refId': '4lhq9'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(irate(node_network_receive_packets_total{instance="worknode:9100", job="node_exporter"}[$__interval]))',
#   'legendFormat': 'host_network_io_packets_receive',
#   'range': True,
#   'refId': 'rptGk'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(irate(node_network_transmit_packets_total{instance="worknode:9100", job="node_exporter"}[$__interval]))',
#   'hide': False,
#   'legendFormat': 'host_network_io_packets_transmit',
#   'range': True,
#   'refId': 'lgj8q'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(node_disk_read_bytes_total{instance="worknode:9100", job="node_exporter"}[$__interval]))',
#   'legendFormat': 'host_block_io_bytes_read',
#   'range': True,
#   'refId': 'OtqDA'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(node_disk_written_bytes_total{instance="worknode:9100", job="node_exporter"}[$__interval]))',
#   'hide': False,
#   'legendFormat': 'host_block_io_bytes_write',
#   'range': True,
#   'refId': '8beoQ'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(node_disk_read_time_seconds_total[$__interval]))',
#   'legendFormat': 'host_block_io_time_read',
#   'range': True,
#   'refId': '9Uw0H'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(node_disk_write_time_seconds_total[$__interval]))',
#   'hide': False,
#   'legendFormat': 'host_block_io_time_write',
#   'range': True,
#   'refId': 'qZzG1'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(irate(ebpf_exporter_syscalls_count_per_cgroup{job="ebpf_exporter", instance="worknode:9435", cgroup=~"/sys/fs/cgroup/machine.slice/machine-qemu\\\\\\\\x2d5\\\\\\\\x2d.*/emulator"}[$__interval])) by (syscall)',
#   'legendFormat': 'vm_hypervisor_emulator_syscall_count_{{syscall}}',
#   'range': True,
#   'refId': 'PTn4h'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(delta(ebpf_exporter_syscalls_sum_per_cgroup{job="ebpf_exporter", instance="worknode:9435", cgroup=~"/sys/fs/cgroup/machine.slice/machine-qemu\\\\\\\\x2d5\\\\\\\\x2d.*/emulator"}[$__interval])) by (syscall) \r\n/ on(syscall)\r\nclamp_min(sum(delta(ebpf_exporter_syscalls_count_per_cgroup{job="ebpf_exporter", instance="worknode:9435", cgroup=~"/sys/fs/cgroup/machine.slice/machine-qemu\\\\\\\\x2d5\\\\\\\\x2d.*/emulator"}[$__interval])) by (syscall), 1)',
#   'legendFormat': 'vm_hypervisor_emulator_syscall_duration_{{syscall}}',
#   'range': True,
#   'refId': 'knHH4'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(irate(ebpf_exporter_syscalls_count_per_cgroup{job="ebpf_exporter", instance="worknode:9435", cgroup=~"/sys/fs/cgroup/machine.slice/machine-qemu\\\\\\\\x2d5\\\\\\\\x2d.*/vcpu.*"}[$__interval])) by (syscall)',
#   'legendFormat': 'vm_hypervisor_vcpu_syscall_count_{{syscall}}',
#   'range': True,
#   'refId': '02GOA'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(delta(ebpf_exporter_syscalls_sum_per_cgroup{job="ebpf_exporter", instance="worknode:9435", cgroup=~"/sys/fs/cgroup/machine.slice/machine-qemu\\\\\\\\x2d5\\\\\\\\x2d.*/vcpu.*"}[$__interval])) by (syscall) \r\n/ on(syscall)\r\nclamp_min(sum(delta(ebpf_exporter_syscalls_count_per_cgroup{job="ebpf_exporter", instance="worknode:9435", cgroup=~"/sys/fs/cgroup/machine.slice/machine-qemu\\\\\\\\x2d5\\\\\\\\x2d.*/vcpu.*"}[$__interval])) by (syscall), 1)',
#   'legendFormat': 'vm_hypervisor_vcpu_syscall_duration_{{syscall}}',
#   'range': True,
#   'refId': 'E035v'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'clamp_min(rate(libvirt_domain_cpu_time_sys{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval]), 0) / 1000',
#   'legendFormat': 'vm_cpu_time_sys',
#   'range': True,
#   'refId': 'MCdX0'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'clamp_min(irate(libvirt_domain_cpu_time_user{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval]), 0) / 1000',
#   'hide': False,
#   'legendFormat': 'vm_cpu_time_user',
#   'range': True,
#   'refId': 'ArHgW'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_vcpu_time_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain) / 1000',
#   'legendFormat': 'vm_cpu_vcpu_time_per_seconds_vcpu',
#   'range': True,
#   'refId': 'Ycrpv'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'clamp_min(idelta(libvirt_domain_perf_count{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter", event="context_switch"}[$__interval]) , 0)',
#   'legendFormat': 'vm_cpu_context_switch_context_switch',
#   'range': True,
#   'refId': 'xSVPG'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'irate(libvirt_domain_perf_count{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter", event="branch_instructions"}[$__interval])',
#   'legendFormat': 'vm_cpu_branch_ips',
#   'range': True,
#   'refId': 'kn9UB'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'clamp_min(delta(libvirt_domain_perf_count{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter", event="cpu_cycles"}[$__interval]), 0)\n/on(domain)\nclamp_min(delta(libvirt_domain_perf_count{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter", event="instructions"}[$__interval]), 1)',
#   'legendFormat': 'vm_cpu_cycle_per_instruction_cpi',
#   'range': True,
#   'refId': '1E5Gm'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'rate(libvirt_domain_perf_count{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter", event="instructions"}[$__interval])',
#   'legendFormat': 'vm_cpu_instructions_per_second_ins',
#   'range': True,
#   'refId': 'lSe8H'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': '1000 * clamp_min(delta(libvirt_domain_perf_count{domain="podman-alpine317_default",instance="worknode:9177", job="libvirt_exporter",event="branch_misses"}[$__interval]), 0)\r\n/on(domain)\r\nclamp_min(delta(libvirt_domain_perf_count{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter", event="branch_instructions"}[$__interval]), 0)',
#   'legendFormat': 'vm_cpu_branch_miss_per_branch_instructions',
#   'range': True,
#   'refId': 'CUd2A'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': '1000 * clamp_min(idelta(libvirt_domain_perf_count{domain="podman-alpine317_default",instance="worknode:9177", job="libvirt_exporter",event="cache_misses"}[$__interval]), 0)\n/on(domain)\nclamp_min(idelta(libvirt_domain_perf_count{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter", event="instructions"}[$__interval]), 0)',
#   'legendFormat': 'vm_cache_misses_per_thousand_instructions',
#   'range': True,
#   'refId': 'MaB3b'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'resctrl_llc_occupancy_bytes{group="podman-alpine317_default", job="resctrl_exporter", instance="worknode:9900"} / 1024 / 28160',
#   'legendFormat': 'vm_cache_last-level_cache_capacity_vm_occupancy_numa_{{numa}}',
#   'range': True,
#   'refId': 'rkMtT'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': '100 * (libvirt_domain_memory_stats_available_bytes{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}\r\n - libvirt_domain_memory_stats_unused_bytes{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"})\r\n / libvirt_domain_memory_stats_actual_balloon_bytes{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}',
#   'legendFormat': 'vm_mem_usage',
#   'range': True,
#   'refId': 'dVAgA'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'irate(resctrl_mem_bandwidth_local_bytes{group="podman-alpine317_default", job="resctrl_exporter", instance="worknode:9900"}[$__interval]) / 1024 / 1024',
#   'legendFormat': 'vm_mem_bandwidth_local_local_numa_{{numa}}',
#   'range': True,
#   'refId': '1nyFc'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'irate(resctrl_mem_bandwidth_total_bytes{group="podman-alpine317_default", job="resctrl_exporter", instance="worknode:9900"}[$__interval]) / 1024 / 1024',
#   'hide': False,
#   'legendFormat': 'vm_mem_bandwidth_local_total_numa_{{numa}}',
#   'range': True,
#   'refId': 'hpwbx'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_interface_stats_receive_bytes_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain, instance) / 1024',
#   'legendFormat': 'vm_network_io_bytes_receive',
#   'range': True,
#   'refId': 'rPIel'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_interface_stats_transmit_bytes_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain, instance) / 1024',
#   'hide': False,
#   'legendFormat': 'vm_network_io_bytes_transmit',
#   'range': True,
#   'refId': 'wrDVZ'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_interface_stats_receive_packets_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain, instance)',
#   'legendFormat': 'vm_network_io_packets_receive',
#   'range': True,
#   'refId': 'fzwMZ'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_interface_stats_transmit_packets_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain, instance)',
#   'hide': False,
#   'legendFormat': 'vm_network_io_packets_transmit',
#   'range': True,
#   'refId': '5Lsu8'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_block_stats_read_bytes_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain)',
#   'legendFormat': 'vm_block_io_bytes_io_read',
#   'range': True,
#   'refId': 'Di1YH'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_block_stats_write_bytes_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain)',
#   'hide': False,
#   'legendFormat': 'vm_block_io_bytes_io_write',
#   'range': True,
#   'refId': 'kHMBd'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_block_stats_write_requests_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain, instance, job)',
#   'legendFormat': 'vm_block_io_requests_write',
#   'range': True,
#   'refId': 'PSEOg'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_block_stats_read_requests_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain, instance, job)',
#   'hide': False,
#   'legendFormat': 'vm_block_io_requests_read',
#   'range': True,
#   'refId': 'cCFXg'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'sum(rate(libvirt_domain_block_stats_write_time_seconds_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain, instance, job)',
#   'legendFormat': 'vm_block_io_time_write',
#   'range': True,
#   'refId': 'a1GQe'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'exemplar': False,
#   'expr': 'sum(rate(libvirt_domain_block_stats_read_time_seconds_total{domain="podman-alpine317_default", instance="worknode:9177", job="libvirt_exporter"}[$__interval])) by(domain, instance, job)',
#   'hide': False,
#   'legendFormat': 'vm_block_io_time_read',
#   'range': True,
#   'refId': '9wP8y'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'rate(libvirt_domain_block_stats_flush_requests_total{domain="podman-alpine317_default",instance="worknode:9177",job="libvirt_exporter"}[$__interval])',
#   'legendFormat': 'vm_block_io_flush_request_and_time_request_{{target_device}}',
#   'range': True,
#   'refId': '3jTfK'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'rate(libvirt_domain_block_stats_flush_time_seconds_total{domain="podman-alpine317_default",instance="worknode:9177",job="libvirt_exporter"}[$__interval])',
#   'hide': False,
#   'legendFormat': 'vm_block_io_flush_request_and_time_time_{{target_device}}',
#   'range': True,
#   'refId': 'c4lY8'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'libvirt_domain_block_stats_allocation{domain="podman-alpine317_default",instance="worknode:9177",job="libvirt_exporter"}',
#   'legendFormat': 'vm_block_io_sector_offset_offset_{{target_device}}',
#   'range': True,
#   'refId': 'cZe2W'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'libvirt_domain_block_stats_size_iops_bytes{domain="podman-alpine317_default",instance="worknode:9177",job="libvirt_exporter"}',
#   'legendFormat': 'vm_block_io_iops_iops_{{target_device}}',
#   'range': True,
#   'refId': 'LW6ie'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'irate(envoy_redis_command_get_error[1m]) + irate(envoy_redis_command_set_error[1m])',
#   'legendFormat': 'app__qps_error',
#   'range': True,
#   'refId': 'SHefG'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'irate(envoy_redis_command_get_total[$__interval])',
#   'hide': False,
#   'legendFormat': 'app_redis_qos_qps_of_redis_get',
#   'range': True,
#   'refId': 'DD581'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'irate(envoy_redis_command_set_total[$__interval])',
#   'hide': False,
#   'legendFormat': 'app_redis_qos_qps_of_redis_set',
#   'range': True,
#   'refId': 'E0SVh'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'irate(envoy_redis_command_get_total[$__interval]) + irate(envoy_redis_command_set_total[$__interval])',
#   'legendFormat': 'app_redis_qos_qps_of_redis_total',
#   'range': True,
#   'refId': 'J0xsV'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'histogram_quantile(0.99, sum by(le) (irate(envoy_redis_command_set_latency_bucket[$__interval]))) / 1000',
#   'legendFormat': 'app_redis_qos_p99_latency_set',
#   'range': True,
#   'refId': 's4SaB'},
#  {'datasource': {'type': 'prometheus', 'uid': 'master_prometheus'},
#   'editorMode': 'code',
#   'expr': 'histogram_quantile(0.99, sum by(le) (irate(envoy_redis_command_get_latency_bucket[$__interval]))) / 1000',
#   'hide': False,
#   'legendFormat': 'app_redis_qos_p99_latency_get',
#   'range': True,
#   'refId': 'yfsLK'}]
